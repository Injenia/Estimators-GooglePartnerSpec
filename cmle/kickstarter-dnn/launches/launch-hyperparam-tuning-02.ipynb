# %%
import tensorflow as tf
import pandas as pd
import os
import json
import shutil
from tensorflow.python.lib.io.file_io import FileIO as open_file
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
DATASET_CSV="gs://ml-research-injenia/estimators/datasets/kickstarter-set/2016_trainset.csv"
EVALSET_CSV="gs://ml-research-injenia/estimators/datasets/kickstarter-set/2016_evalset.csv"
MODEL_DIR="gs://ml-research-injenia/estimators/trainings-kickstarter-v2/dnn-classifier/test02"

#BATCH_SIZE = 100
TRAIN_STEPS= 1000000
#LEARNING_RATE=0.01
L1_NORM=0.0
L2_NORM=0.0

#HIDDEN_UNITS=[1024, 512, 256]
#EMBEDDING_COLUMNS_SIZE=4

# %%
with open_file(DATASET_CSV, "r") as f:
    df = pd.read_csv(f)
df
# Out:
#                 ID          category main_category currency       state  \
# 0       1892252564       Comic Books        Comics      USD  successful
# 1       1569410360       Documentary  Film & Video      USD      failed
# 2        703720557      Illustration           Art      USD      failed
# 3        296713470       Photography   Photography      USD  successful
# 4        156448762    Product Design        Design      USD      failed
# 5       1255814383             Music         Music      USD  successful
# 6        697900694       Video Games         Games      CAD      failed
# 7       1026864342      Civic Design        Design      EUR      failed
# 8       1923292016  Farmer's Markets          Food      GBP      failed
# 9        317811128        Publishing    Publishing      USD      failed
# 10      1886283141  Children's Books    Publishing      USD      failed
# 11       472784336           Musical       Theater      USD  successful
# 12      1045472649           Fashion       Fashion      USD      failed
# 13       494118228            Comics        Comics      USD      failed
# 14        85780162       Accessories       Fashion      USD      failed
# 15       582987214              Food          Food      USD      failed
# 16      1743903226         Sculpture           Art      USD      failed
# 17      1233251974  Children's Books    Publishing      USD      failed
# 18      2134490157      Architecture        Design      USD      failed
# 19        82363802    Product Design        Design      USD      failed
# 20       330053392       Video Games         Games      CAD      failed
# 21       237833701               Web    Technology      CAD      failed
# 22       113535543            Horror  Film & Video      USD  successful
# 23       982631844          Painting           Art      USD  successful
# 24       867350313        Indie Rock         Music      EUR  successful
# 25      1731180575             Music         Music      USD      failed
# 26       554609543    Product Design        Design      USD  successful
# 27       216533452    Tabletop Games         Games      USD  successful
# 28       866844750           Theater       Theater      USD  successful
# 29       808488435               DIY        Crafts      GBP      failed
# ...            ...               ...           ...      ...         ...
# 253142    75241902           Fashion       Fashion      USD      failed
# 253143  1703799277       Restaurants          Food      USD      failed
# 253144   220991046          Hardware    Technology      USD  successful
# 253145    62869379  Electronic Music         Music      USD  successful
# 253146   541988931         Webseries  Film & Video      USD  successful
# 253147  1241268882       Digital Art           Art      GBP      failed
# 253148  1644510651  Electronic Music         Music      EUR  successful
# 253149   990534577             Dance         Dance      USD  successful
# 253150    64852068           Fashion       Fashion      USD  successful
# 253151   502604168             Music         Music      USD  successful
# 253152   532669939        Photobooks   Photography      EUR  successful
# 253153   446083085            Shorts  Film & Video      USD      failed
# 253154  1563321223    Tabletop Games         Games      USD      failed
# 253155   647874091        Indie Rock         Music      USD  successful
# 253156   246651208           Theater       Theater      USD  successful
# 253157   798753050            Comics        Comics      USD  successful
# 253158  1346643325           Fiction    Publishing      USD      failed
# 253159  1441368384             Video    Journalism      USD      failed
# 253160  1283548494       3D Printing    Technology      USD      failed
# 253161  1686698827      Film & Video  Film & Video      GBP      failed
# 253162  2131637010    Product Design        Design      USD      failed
# 253163  1101099474       Documentary  Film & Video      USD  successful
# 253164   144348808          Software    Technology      USD      failed
# 253165  1544187522        Technology    Technology      USD      failed
# 253166   588293490            Drinks          Food      USD      failed
# 253167  2041791881              Food          Food      USD      failed
# 253168  1314495131            Spaces          Food      USD  successful
# 253169  1620701015       Documentary  Film & Video      CAD      failed
# 253170  1016931493     Installations           Art      USD      failed
# 253171   586351286              Punk         Music      USD      failed
#
#        country  timespan_days       goal_USD  goal_USD_log  \
# 0           US           30.0    2500.000000      7.824046
# 1           US           60.0    2000.000000      7.600902
# 2           US           30.0    2700.000000      7.901007
# 3           US           30.0    5000.000000      8.517193
# 4           US           30.0   15000.000000      9.615805
# 5           US           30.0  100000.000000     11.512925
# 6           CA           30.0    1199.461089      7.089628
# 7           IT           60.0   24928.000000     10.123747
# 8           GB           25.0     140.355619      4.944179
# 9           US           29.0   15000.000000      9.615805
# 10          US           29.0   20000.000000      9.903488
# 11          US           30.0    1000.000000      6.907755
# 12          US           15.0    1000.000000      6.907755
# 13          US           60.0   30000.000000     10.308953
# 14          US           30.0   15000.000000      9.615805
# 15          US           31.0     500.000000      6.214608
# 16          US           60.0   38000.000000     10.545341
# 17          US           33.0     750.000000      6.620073
# 18          US           30.0   25000.000000     10.126631
# 19          US           30.0   79000.000000     11.277203
# 20          CA           30.0   55974.850837     10.932658
# 21          CA           30.0   14393.533072      9.574534
# 22          US           30.0    1500.000000      7.313220
# 23          US           34.0    3000.000000      8.006368
# 24          BE           52.0    3739.200000      8.226627
# 25          US           30.0    2500.000000      7.824046
# 26          US           30.0     500.000000      6.214608
# 27          US           31.0   10000.000000      9.210340
# 28          US           31.0    6500.000000      8.779557
# 29          GB           32.0    6316.002838      8.750842
# ...        ...            ...            ...           ...
# 253142      US           10.0   20000.000000      9.903488
# 253143      US           45.0   30000.000000     10.308953
# 253144      US           30.0     110.000000      4.700480
# 253145      US           30.0   10000.000000      9.210340
# 253146      US           31.0    6000.000000      8.699515
# 253147      GB           20.0    4210.668558      8.345377
# 253148      NL           30.0    4985.600000      8.514309
# 253149      US           30.0    5000.000000      8.517193
# 253150      US           15.0     500.000000      6.214608
# 253151      US           45.0   18000.000000      9.798127
# 253152      NL           30.0   31160.000000     10.346890
# 253153      US           53.0    3000.000000      8.006368
# 253154      US           30.0    5000.000000      8.517193
# 253155      US           23.0   10000.000000      9.210340
# 253156      US           36.0    1500.000000      7.313220
# 253157      US           33.0   20000.000000      9.903488
# 253158      US           27.0    7300.000000      8.895630
# 253159      US           30.0    5000.000000      8.517193
# 253160      US           46.0   50000.000000     10.819778
# 253161      GB           40.0   70177.809308     11.158787
# 253162      US           30.0     600.000000      6.396930
# 253163      US           30.0    8500.000000      9.047821
# 253164      US           30.0   20000.000000      9.903488
# 253165      US           60.0  100000.000000     11.512925
# 253166      US           30.0    1800.000000      7.495542
# 253167      US           30.0   10000.000000      9.210340
# 253168      US           28.0   40000.000000     10.596635
# 253169      CA           30.0    7996.407262      8.986748
# 253170      US           30.0    5000.000000      8.517193
# 253171      US           30.0   40000.000000     10.596635
#
#         timespan_days_scaled  goal_USD_scaled  goal_USD_log_scaled
# 0                  -0.308155        -0.036034            -0.453981
# 1                   2.019002        -0.036501            -0.587792
# 2                  -0.308155        -0.035847            -0.407830
# 3                  -0.308155        -0.033698            -0.038326
# 4                  -0.308155        -0.024352             0.620471
# 5                  -0.308155         0.055088             1.758104
# 6                  -0.308155        -0.037249            -0.894384
# 7                   2.019002        -0.015073             0.925065
# 8                  -0.696015        -0.038239            -2.180931
# 9                  -0.385727        -0.024352             0.620471
# 10                 -0.385727        -0.019679             0.792984
# 11                 -0.308155        -0.037436            -1.003446
# 12                 -1.471734        -0.037436            -1.003446
# 13                  2.019002        -0.010333             1.036126
# 14                 -0.308155        -0.024352             0.620471
# 15                 -0.230583        -0.037903            -1.419101
# 16                  2.019002        -0.002856             1.177880
# 17                 -0.075439        -0.037669            -1.175959
# 18                 -0.308155        -0.015006             0.926795
# 19                 -0.308155         0.035462             1.616750
# 20                 -0.308155         0.013943             1.410139
# 21                 -0.308155        -0.024918             0.595723
# 22                 -0.308155        -0.036969            -0.760304
# 23                  0.002132        -0.035567            -0.344649
# 24                  1.398427        -0.034876            -0.212568
# 25                 -0.308155        -0.036034            -0.453981
# 26                 -0.308155        -0.037903            -1.419101
# 27                 -0.230583        -0.029025             0.377329
# 28                 -0.230583        -0.032296             0.119004
# 29                 -0.153011        -0.032468             0.101785
# ...                      ...              ...                  ...
# 253142             -1.859593        -0.019679             0.792984
# 253143              0.855423        -0.010333             1.036126
# 253144             -0.308155        -0.038268            -2.327068
# 253145             -0.308155        -0.029025             0.377329
# 253146             -0.230583        -0.032763             0.071006
# 253147             -1.083874        -0.034435            -0.141358
# 253148             -0.308155        -0.033711            -0.040055
# 253149             -0.308155        -0.033698            -0.038326
# 253150             -1.471734        -0.037903            -1.419101
# 253151              0.855423        -0.021548             0.729803
# 253152             -0.308155        -0.009249             1.058876
# 253153              1.475999        -0.035567            -0.344649
# 253154             -0.308155        -0.033698            -0.038326
# 253155             -0.851158        -0.029025             0.377329
# 253156              0.157276        -0.036969            -0.760304
# 253157             -0.075439        -0.019679             0.792984
# 253158             -0.540871        -0.031548             0.188609
# 253159             -0.308155        -0.033698            -0.038326
# 253160              0.932995         0.008359             1.342450
# 253161              0.467564         0.027217             1.545741
# 253162             -0.308155        -0.037810            -1.309770
# 253163             -0.308155        -0.030426             0.279872
# 253164             -0.308155        -0.019679             0.792984
# 253165              2.019002         0.055088             1.758104
# 253166             -0.308155        -0.036688            -0.650972
# 253167             -0.308155        -0.029025             0.377329
# 253168             -0.463299        -0.000987             1.208639
# 253169             -0.308155        -0.030897             0.243249
# 253170             -0.308155        -0.033698            -0.038326
# 253171             -0.308155        -0.000987             1.208639
#
# [253172 rows x 12 columns]

# %%
with open_file(EVALSET_CSV, "r") as f:
    df_eval = pd.read_csv(f)
df_eval
# Out:
#                ID          category main_category currency       state  \
# 0       153415837            Flight    Technology      USD      failed
# 1      1828026144          Fine Art   Photography      USD      failed
# 2       919600393  Children's Books    Publishing      USD      failed
# 3      1621230227       Comic Books        Comics      USD      failed
# 4       954788005           Theater       Theater      USD  successful
# 5      1094453155            Flight    Technology      USD      failed
# 6       536236122      Experimental  Film & Video      USD  successful
# 7      2076494684            Quilts        Crafts      USD      failed
# 8        70609801       Young Adult    Publishing      EUR      failed
# 9      1269516548    Product Design        Design      USD  successful
# 10     1106675251       Restaurants          Food      USD      failed
# 11      237144285       Video Games         Games      EUR      failed
# 12     1859302023            Crafts        Crafts      USD  successful
# 13      306847193           Apparel       Fashion      GBP      failed
# 14      327433179             Games         Games      USD      failed
# 15      429847734        Publishing    Publishing      CAD  successful
# 16     1362853434    Product Design        Design      CAD  successful
# 17     1930788877              Food          Food      EUR      failed
# 18     2029875015       Comic Books        Comics      GBP      failed
# 19     2121973368   Performance Art           Art      USD  successful
# 20     2054137331   Classical Music         Music      AUD  successful
# 21      671754438       Photography   Photography      USD      failed
# 22       35403397              Apps    Technology      EUR      failed
# 23     2135429817            Comics        Comics      USD  successful
# 24      464312746       Anthologies    Publishing      CAD      failed
# 25     1169882740       Small Batch          Food      USD      failed
# 26      491412194              Apps    Technology      USD      failed
# 27      637263714            Comics        Comics      CAD  successful
# 28     1702992799            Crafts        Crafts      USD  successful
# 29      151192525      Mobile Games         Games      AUD      failed
# ...           ...               ...           ...      ...         ...
# 28100  1420361126    Tabletop Games         Games      USD  successful
# 28101  1287407738            Shorts  Film & Video      USD  successful
# 28102  1561587538  Children's Books    Publishing      CAD      failed
# 28103   169669071       Documentary  Film & Video      USD      failed
# 28104   638200193       3D Printing    Technology      AUD  successful
# 28105  1247871276         Webseries  Film & Video      CAD      failed
# 28106  1884500951           Hip-Hop         Music      USD      failed
# 28107   289959673          Academic    Publishing      CAD      failed
# 28108  1259896439        Indie Rock         Music      USD  successful
# 28109  1038418119    Product Design        Design      USD      failed
# 28110   142462051    Conceptual Art           Art      GBP  successful
# 28111  1306152209      Architecture        Design      USD  successful
# 28112   603980828    Tabletop Games         Games      USD      failed
# 28113   566978186           Hip-Hop         Music      USD  successful
# 28114  1729785841              Jazz         Music      USD      failed
# 28115  1550121438      Film & Video  Film & Video      USD      failed
# 28116  1283011729             Music         Music      USD      failed
# 28117   317348137    Narrative Film  Film & Video      USD  successful
# 28118  2130003984      Film & Video  Film & Video      USD  successful
# 28119  1264216628        Live Games         Games      USD  successful
# 28120   993116639  Children's Books    Publishing      USD      failed
# 28121   369628356           Apparel       Fashion      GBP      failed
# 28122   493211291    Tabletop Games         Games      USD      failed
# 28123   754669207        Nonfiction    Publishing      USD      failed
# 28124  1327798759              Rock         Music      USD  successful
# 28125   391623651       Comic Books        Comics      USD  successful
# 28126  1815738806             Music         Music      NZD  successful
# 28127  1361732153       Accessories       Fashion      USD      failed
# 28128  1245729137        Nonfiction    Publishing      AUD      failed
# 28129  1762850365             Plays       Theater      USD      failed
#
#       country  timespan_days      goal_USD  goal_USD_log  \
# 0          US           30.0  1.500000e+04      9.615805
# 1          US           31.0  6.500001e+06     15.687313
# 2          US           32.0  2.000000e+03      7.600902
# 3          US           30.0  4.000000e+03      8.294050
# 4          US           14.0  3.500000e+03      8.160518
# 5          US           53.0  1.000000e+04      9.210340
# 6          US           17.0  2.500000e+01      3.218876
# 7          US           28.0  1.800000e+03      7.495542
# 8          DE           60.0  1.246400e+04      9.430600
# 9          US           30.0  7.500000e+03      8.922658
# 10         US           19.0  6.300000e+03      8.748305
# 11         FR           30.0  1.869600e+04      9.836065
# 12         US           12.0  1.000000e+03      6.907755
# 13         GB           30.0  8.421337e+03      9.038524
# 14         US           30.0  2.500000e+03      7.824046
# 15         CA           36.0  1.439353e+03      7.271949
# 16         CA           30.0  1.999102e+04      9.903038
# 17         IT           60.0  4.362400e+05     12.985948
# 18         GB           30.0  6.316003e+03      8.750842
# 19         US           30.0  1.000000e+04      9.210340
# 20         AU           44.0  1.588277e+03      7.370405
# 21         US           60.0  5.000000e+02      6.214608
# 22         NL           30.0  2.492800e+05     12.426332
# 23         US           29.0  1.000000e+03      6.907755
# 24         CA           21.0  1.991105e+04      9.899030
# 25         US           30.0  5.000000e+01      3.912023
# 26         US           30.0  3.234800e+04     10.384307
# 27         CA           28.0  2.398922e+03      7.782775
# 28         US           14.0  3.000000e+02      5.703782
# 29         AU           30.0  2.382415e+04     10.078455
# ...       ...            ...           ...           ...
# 28100      US           30.0  2.000000e+02      5.298317
# 28101      US           32.0  3.500000e+03      8.160518
# 28102      CA           30.0  2.398922e+02      5.480190
# 28103      US           60.0  1.000000e+04      9.210340
# 28104      AU           30.0  4.367760e+03      8.382006
# 28105      CA           30.0  1.199461e+04      9.392213
# 28106      US           15.0  1.000000e+03      6.907755
# 28107      CA           45.0  1.599281e+02      5.074725
# 28108      US           30.0  4.000000e+03      8.294050
# 28109      US           30.0  1.600000e+04      9.680344
# 28110      GB           26.0  7.017781e+02      6.553617
# 28111      US           33.0  1.000000e+03      6.907755
# 28112      US           33.0  6.000000e+03      8.699515
# 28113      US           30.0  5.000000e+02      6.214608
# 28114      US           60.0  1.500000e+04      9.615805
# 28115      US           31.0  5.000000e+04     10.819778
# 28116      US           89.0  3.000000e+03      8.006368
# 28117      US            7.0  3.000000e+02      5.703782
# 28118      US           30.0  3.000000e+03      8.006368
# 28119      US           30.0  5.000000e+02      6.214608
# 28120      US           30.0  1.000000e+04      9.210340
# 28121      GB           30.0  3.508890e+02      5.860470
# 28122      US           30.0  1.250000e+05     11.736069
# 28123      US           29.0  6.700000e+03      8.809863
# 28124      US           25.0  5.500000e+02      6.309918
# 28125      US           30.0  2.000000e+03      7.600902
# 28126      NZ           27.0  7.395716e+03      8.908656
# 28127      US           30.0  7.000000e+03      8.853665
# 28128      AU           30.0  2.779484e+04     10.232606
# 28129      US           60.0  5.500000e+03      8.612503
#
#        timespan_days_scaled  goal_USD_scaled  goal_USD_log_scaled
# 0                 -0.308155        -0.024352             0.620471
# 1                 -0.230583         6.036428             4.261331
# 2                 -0.153011        -0.036501            -0.587792
# 3                 -0.308155        -0.034632            -0.172137
# 4                 -1.549306        -0.035099            -0.252211
# 5                  1.475999        -0.029025             0.377329
# 6                 -1.316590        -0.038347            -3.215532
# 7                 -0.463299        -0.036688            -0.650972
# 8                  2.019002        -0.026722             0.509410
# 9                 -0.308155        -0.031361             0.204817
# 10                -1.161446        -0.032483             0.100263
# 11                -0.308155        -0.020897             0.752553
# 12                -1.704449        -0.037436            -1.003446
# 13                -0.308155        -0.030500             0.274297
# 14                -0.308155        -0.036034            -0.453981
# 15                 0.157276        -0.037025            -0.785053
# 16                -0.308155        -0.019687             0.792714
# 17                 2.019002         0.369333             2.641422
# 18                -0.308155        -0.032468             0.101785
# 19                -0.308155        -0.029025             0.377329
# 20                 0.777851        -0.036886            -0.726013
# 21                 2.019002        -0.037903            -1.419101
# 22                -0.308155         0.194603             2.305841
# 23                -0.385727        -0.037436            -1.003446
# 24                -1.006302        -0.019762             0.790311
# 25                -0.308155        -0.038324            -2.799877
# 26                -0.308155        -0.008139             1.081314
# 27                -0.463299        -0.036128            -0.478729
# 28                -1.549306        -0.038090            -1.725425
# 29                -0.308155        -0.016105             0.897905
# ...                     ...              ...                  ...
# 28100             -0.308155        -0.038184            -1.968567
# 28101             -0.153011        -0.035099            -0.252211
# 28102             -0.308155        -0.038146            -1.859505
# 28103              2.019002        -0.029025             0.377329
# 28104             -0.308155        -0.034288            -0.119393
# 28105             -0.308155        -0.027160             0.486391
# 28106             -1.471734        -0.037436            -1.003446
# 28107              0.855423        -0.038221            -2.102647
# 28108             -0.308155        -0.034632            -0.172137
# 28109             -0.308155        -0.023417             0.659173
# 28110             -0.618443        -0.037715            -1.215810
# 28111             -0.075439        -0.037436            -1.003446
# 28112             -0.075439        -0.032763             0.071006
# 28113             -0.308155        -0.037903            -1.419101
# 28114              2.019002        -0.024352             0.620471
# 28115             -0.230583         0.008359             1.342450
# 28116              4.268587        -0.035567            -0.344649
# 28117             -2.092309        -0.038090            -1.725425
# 28118             -0.308155        -0.035567            -0.344649
# 28119             -0.308155        -0.037903            -1.419101
# 28120             -0.308155        -0.029025             0.377329
# 28121             -0.308155        -0.038042            -1.631465
# 28122             -0.308155         0.078453             1.891915
# 28123             -0.385727        -0.032109             0.137177
# 28124             -0.696015        -0.037856            -1.361947
# 28125             -0.308155        -0.036501            -0.587792
# 28126             -0.540871        -0.031459             0.196420
# 28127             -0.308155        -0.031828             0.163444
# 28128             -0.308155        -0.012394             0.990344
# 28129              2.019002        -0.033230             0.018828
#
# [28130 rows x 12 columns]

# %%
with open_file(os.path.join(MODEL_DIR,"trainset.csv"), "w") as f:
    df.to_csv(f,index=False)
with open_file(os.path.join(MODEL_DIR,"evalset.csv"), "w") as f:
    df_eval.to_csv(f,index=False)

# %%
INDEX="ID"
COLUMNS=[
    "category",
    "main_category",
    "state",
    "country",
    "timespan_days_scaled",
    "goal_USD_scaled",
    "goal_USD_log_scaled"
]
LABEL_FIELD="state"

# %%
FIELD_DEFAULTS=[]
FIELD_TYPES={}
FIELD_CATEGORIES={}
dtypes=dict(df.dtypes)
for c in COLUMNS:
    if(str(dtypes[c])=="bool"):
        FIELD_DEFAULTS.append([0])
        FIELD_TYPES[c]="bool"
    elif(str(dtypes[c])=="object"):
        FIELD_DEFAULTS.append(["NA"])
        FIELD_TYPES[c]="string"
        FIELD_CATEGORIES[c]=list(sorted(set(list(df[c].unique())+["NA"])))
    else:  
        FIELD_DEFAULTS.append([0.0])
        FIELD_TYPES[c]="number"
FIELD_CATEGORIES[LABEL_FIELD]=[x for x in FIELD_CATEGORIES[LABEL_FIELD] if x != "NA"]

# %%
with open_file(os.path.join(MODEL_DIR,"data","dataset_fields.json"), "w") as f:
    json.dump(
        {
            "fields":{
                "columns" : COLUMNS,#[x for x in COLUMNS if x != LABEL_FIELD],
                "types" : FIELD_TYPES,#{x:FIELD_TYPES[x] for x in FIELD_TYPES if x != LABEL_FIELD},
                "categories" : FIELD_CATEGORIES,#{x:FIELD_CATEGORIES[x] for x in FIELD_CATEGORIES if x != LABEL_FIELD}
            },
            "label":{
                "column" : LABEL_FIELD,
                "type" : FIELD_TYPES[LABEL_FIELD],
                "categories" : FIELD_CATEGORIES[LABEL_FIELD],
            }
        },
        f
    )

# %%
with open_file(os.path.join(MODEL_DIR,"data","tf_trainset.csv"), "w") as f:
    df[COLUMNS].to_csv(f, index=False)
with open_file(os.path.join(MODEL_DIR,"data","tf_evalset.csv"), "w") as f:
    df_eval[COLUMNS].to_csv(f, index=False)

# %% [markdown]
# ## hyperparam.yaml

# %%
config="""trainingInput:
  scaleTier: STANDARD_1
  hyperparameters:
    goal: MAXIMIZE
    hyperparameterMetricTag: accuracy
    maxTrials: 50
    maxParallelTrials: 10
    params:
    - parameterName: LEARNING_RATE
      type: DOUBLE
      minValue: 0.000001
      maxValue: 0.01
      scaleType: UNIT_LOG_SCALE
    - parameterName: BATCH_SIZE
      type: INTEGER
      minValue: 256
      maxValue: 16384
      scaleType: UNIT_LOG_SCALE
    - parameterName: EMBEDDING_COLUMNS_SIZE
      type: INTEGER
      minValue: 4
      maxValue: 64
      scaleType: UNIT_LINEAR_SCALE
    - parameterName: HIDDEN_UNITS
      type: CATEGORICAL
      categoricalValues: ["64,16", "64,16,4", "64,64,64,8", "256,64,16", "512,128,32,8"]
"""

with open_file(os.path.join(MODEL_DIR,"config","hyperparam.yaml"), "w") as f:
    df.to_csv(f,index=False)

print(config)
with open("hyperparam.yaml", "w") as f:
    f.write(config)
    
with open("hyperparam.yaml", "r") as f:
    print(f.read())
# Out:
# trainingInput:
#   scaleTier: STANDARD_1
#   hyperparameters:
#     goal: MAXIMIZE
#     hyperparameterMetricTag: accuracy
#     maxTrials: 50
#     maxParallelTrials: 10
#     params:
#     - parameterName: LEARNING_RATE
#       type: DOUBLE
#       minValue: 0.000001
#       maxValue: 0.01
#       scaleType: UNIT_LOG_SCALE
#     - parameterName: BATCH_SIZE
#       type: INTEGER
#       minValue: 256
#       maxValue: 16384
#       scaleType: UNIT_LOG_SCALE
#     - parameterName: EMBEDDING_COLUMNS_SIZE
#       type: INTEGER
#       minValue: 4
#       maxValue: 64
#       scaleType: UNIT_LINEAR_SCALE
#     - parameterName: HIDDEN_UNITS
#       type: CATEGORICAL
#       categoricalValues: ["64,16", "64,16,4", "64,64,64,8", "256,64,16", "512,128,32,8"]
#
# trainingInput:
#   scaleTier: STANDARD_1
#   hyperparameters:
#     goal: MAXIMIZE
#     hyperparameterMetricTag: accuracy
#     maxTrials: 50
#     maxParallelTrials: 10
#     params:
#     - parameterName: LEARNING_RATE
#       type: DOUBLE
#       minValue: 0.000001
#       maxValue: 0.01
#       scaleType: UNIT_LOG_SCALE
#     - parameterName: BATCH_SIZE
#       type: INTEGER
#       minValue: 256
#       maxValue: 16384
#       scaleType: UNIT_LOG_SCALE
#     - parameterName: EMBEDDING_COLUMNS_SIZE
#       type: INTEGER
#       minValue: 4
#       maxValue: 64
#       scaleType: UNIT_LINEAR_SCALE
#     - parameterName: HIDDEN_UNITS
#       type: CATEGORICAL
#       categoricalValues: ["64,16", "64,16,4", "64,64,64,8", "256,64,16", "512,128,32,8"]

# %% [markdown]
# # Train

# %%
os.environ['MODEL_DIR'] = str(MODEL_DIR)
os.environ['TRAIN_STEPS'] = str(TRAIN_STEPS)
#os.environ['BATCH_SIZE'] = str(BATCH_SIZE)
#os.environ['LEARNING_RATE'] = str(LEARNING_RATE)
os.environ['L1_NORM'] = str(L1_NORM)
os.environ['L2_NORM'] = str(L2_NORM)

os.environ['BUCKET'] = "ml-research-injenia"
os.environ['REGION'] = 'europe-west1'

# %% [markdown]
# ## Cloud

# %%
# %%bash
#
# JOBNAME=kickstarter_dnn_$(date -u +%y%m%d_%H%M%S)
#
# echo "Launching training job ... trained model will be in $MODEL_DIR"
# #gsutil -m rm -rf $OUTPUT_DIR
# gcloud ml-engine jobs submit training $JOBNAME \
#   --region=$REGION \
#   --module-name=trainer.task \
#   --package-path=$(pwd)/../trainer \
#   --job-dir=$MODEL_DIR \
#   --staging-bucket=gs://$BUCKET-staging \
#   --runtime-version="1.6" \
#   --config=hyperparam.yaml \
#   -- \
#   --MODEL_DIR=$MODEL_DIR \
#   --TRAIN_STEPS $TRAIN_STEPS \
#   --L1_NORM $L1_NORM \
#   --L2_NORM $L2_NORM
# Out:
# Launching training job ... trained model will be in gs://ml-research-injenia/estimators/trainings-kickstarter-v2/dnn-classifier/test02
# jobId: kickstarter_dnn_180911_161344
# state: QUEUED
# Job [kickstarter_dnn_180911_161344] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ml-engine jobs describe kickstarter_dnn_180911_161344
#
# or continue streaming the logs with the command
#
#   $ gcloud ml-engine jobs stream-logs kickstarter_dnn_180911_161344

# %%
import subprocess
import json


def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z


res_str=subprocess.check_output("gcloud ml-engine jobs describe kickstarter_dnn_180911_161344 --format json".split(" "))
res=json.loads(res_str)
trials=res["trainingOutput"]["trials"]
df=pd.DataFrame([
    merge_two_dicts({"trialId":t["trialId"]},
    merge_two_dicts(t["finalMetric"],t["hyperparameters"]) )
    for t in trials])

df
# Out:
#    BATCH_SIZE EMBEDDING_COLUMNS_SIZE  HIDDEN_UNITS           LEARNING_RATE  \
# 0         496                      8     256,64,16   0.0016674848792840155
# 1         269                     39     256,64,16   0.0017348885302416724
# 2         287                     59     256,64,16   0.0020983937295909103
# 3         688                      9     256,64,16   0.0016713875741645294
# 4         325                      7     256,64,16   0.0017574365965561391
# 5        1000                      9     256,64,16   0.0017208058346744135
# 6         314                     16     256,64,16   0.0015708497130074697
# 7        1008                      4     256,64,16   0.0017114638361770168
# 8         280                     62  512,128,32,8   0.0015494474863114575
# 9         278                     18     256,64,16   0.0017243064936862612
# 10        316                     13     256,64,16   0.0016848260703681509
# 11        333                      8     256,64,16   0.0015458581208436658
# 12        288                      6     256,64,16   0.0016535763461439446
# 13        346                      9     256,64,16   0.0017272540391226612
# 14        450                     43     256,64,16   0.0016865026002060657
# 15        299                     63     256,64,16   0.0019968618270199191
# 16        502                     58         64,16    0.003488442536533326
# 17        391                     21     256,64,16   0.0016433853553451921
# 18        698                     63     256,64,16   0.0014417574084272574
# 19        283                     14     256,64,16   0.0017226028344782059
# 20        340                     64     256,64,16   0.0014578173737887564
# 21        272                      4     256,64,16   0.0016061618465425163
# 22        340                     58  512,128,32,8   0.0014183602192457511
# 23       1592                      4         64,16   0.0029832349134834425
# 24       7305                     17    64,64,64,8   0.0002739790159630707
# 25       1343                     62     256,64,16   0.0013556356996690751
# 26        258                     61    64,64,64,8   0.0020526776639254929
# 27        257                     64  512,128,32,8  0.00084818671245588391
# 28        286                     12     256,64,16   0.0013017280346868895
# 29        270                     27     256,64,16     0.00318881660896172
# 30        383                     52  512,128,32,8   0.0015461890977337494
# 31        427                     16       64,16,4    0.001233503345513687
# 32      10586                      4       64,16,4   0.0052883655447658311
# 33        309                     54     256,64,16   0.0024726708156272647
# 34        319                     60         64,16   0.0019195823802287783
# 35        850                     36         64,16   0.0092563779256845478
# 36        286                     15     256,64,16   0.0050402943792893342
# 37       5316                     15     256,64,16   0.0013939603863366414
# 38        569                     59     256,64,16   0.0026922048022511385
# 39        641                     61         64,16   0.0013243420680852035
# 40        397                      7    64,64,64,8  0.00068055251300083231
# 41      13531                      9    64,64,64,8     0.00244564593913922
# 42       3148                     59     256,64,16  3.9941380156376569e-05
# 43      16320                      6     256,64,16   0.0024158618892419379
# 44      12671                     63     256,64,16   0.0021620949864777353
# 45      15369                     37  512,128,32,8  5.2897066388156818e-06
# 46       1235                     59  512,128,32,8   0.0037497849952309579
# 47      14745                     63     256,64,16  1.0218665937751744e-06
# 48       4413                     15         64,16  1.0014978247675705e-06
#
#     objectiveValue trainingStep trialId
# 0         0.687533      1000004      36
# 1         0.687533      1000003      40
# 2         0.687500      1000006       3
# 3         0.687367      1000000      41
# 4         0.687233      1000008      47
# 5         0.687133      1000002      48
# 6         0.687100      1000005      32
# 7         0.686933      1000008      44
# 8         0.686800      1000004      23
# 9         0.686733      1000007      38
# 10        0.686733      1000005      46
# 11        0.686667      1000001      37
# 12        0.686533      1000001      34
# 13        0.686300      1000002       8
# 14        0.686200      1000008      33
# 15        0.686067      1000003      22
# 16        0.686033      1000008       9
# 17        0.685933      1000007      42
# 18        0.685933      1000006      17
# 19        0.685800      1000004      50
# 20        0.685767      1000005      31
# 21        0.685667      1000005      49
# 22        0.685567      1000008      30
# 23        0.685533      1000003       4
# 24        0.685500      1000006       2
# 25        0.685500      1000008      16
# 26        0.685467      1000004       5
# 27        0.685267      1000005      21
# 28        0.685200      1000006      35
# 29        0.685067      1000005      13
# 30        0.684933      1000005      29
# 31        0.684600      1000007      43
# 32        0.684600      1000008      10
# 33        0.684533      1000006      12
# 34        0.684133      1000007      20
# 35        0.682933      1000004      26
# 36        0.682800      1000006      14
# 37        0.682667      1000005      28
# 38        0.682500      1000007      27
# 39        0.682267      1000000      18
# 40        0.681333      1000006      45
# 41        0.680967      1000007       6
# 42        0.678367      1000007      19
# 43        0.676200      1000002      11
# 44        0.672867      1000007       7
# 45        0.663833      1000004       1
# 46        0.662933      1000004      25
# 47        0.627867      1000006      24
# 48        0.469567      1000006      15
