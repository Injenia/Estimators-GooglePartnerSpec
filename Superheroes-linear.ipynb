# %% [markdown]
# # DATASET DEFINITION

# %%
import tensorflow as tf
import pandas as pd
import os
import json
import shutil
from tensorflow.python.lib.io.file_io import FileIO as open_file
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
DATASET_CSV="gs://ml-research-injenia/estimators/datasets/superhero-set/preproc_trainset.csv"
EVALSET_CSV="gs://ml-research-injenia/estimators/datasets/superhero-set/preproc_evalset.csv"
OUT_DIR="gs://ml-research-injenia/estimators/trainings/linear-classifier/test08"
MODEL_DIR=OUT_DIR

BATCH_SIZE = 100
TRAIN_STEPS= 100000

HIDDEN_UNITS=[1024, 512, 256]
EMBEDDING_COLUMNS_SIZE=4

# %%
with open_file(DATASET_CSV, "r") as f:
    df = pd.read_csv(f)
for c in df.columns:
    if df[c].dtypes.name == 'bool':
        df[c]=df[c].map({True: 'TRUE', False: 'FALSE'})
df
# Out:
#                  index  Gender Eye_color               Race     Hair_color  \
# 0           Molten Man    Male      gold                  -           Gold
# 1         Killer Frost  Female      blue              Human          Blond
# 2                Raven  Female    indigo              Human          Black
# 3               Vegeta    Male         -             Saiyan          Black
# 4                  Gog    Male         -                  -              -
# 5          Redeemer II    Male         -                  -              -
# 6    Captain Marvel II    Male      blue              Human          Black
# 7         Proto-Goblin    Male     green                  -          Blond
# 8               Sentry    Male      blue             Mutant          Blond
# 9             Kylo Ren    Male         -              Human              -
# 10               Flash    Male      blue              Human  Brown / White
# 11           Annihilus    Male     green                  -        No Hair
# 12            Snowbird  Female     white                  -          Blond
# 13             Mach-IV    Male     brown                  -          Brown
# 14         Tiger Shark    Male      grey              Human        No Hair
# 15             Ant-Man    Male      blue              Human          Blond
# 16               Curse    Male         -                  -              -
# 17           Simon Baz    Male      bown              Human          Black
# 18           Bumblebee  Female     brown              Human          Black
# 19                Thor    Male      blue          Asgardian          Blond
# 20       Black Panther    Male     brown              Human          Black
# 21             Atom II    Male     brown              Human         Auburn
# 22               Quill    Male     brown                  -          Brown
# 23             Ripcord  Female     green                  -          Black
# 24              Maxima  Female     brown                  -            Red
# 25               K-2SO    Male     white            Android        No Hair
# 26             Aquaman    Male      blue          Atlantean          Blond
# 27              Hollow  Female      blue                  -            Red
# 28           Red Skull    Male      blue                  -        No Hair
# 29              Cyborg    Male     brown             Cyborg          Black
# ..                 ...     ...       ...                ...            ...
# 559           Firelord       -     white                  -         Yellow
# 560              Magog    Male      blue                  -          Blond
# 561    Nathan Petrelli    Male     brown                  -              -
# 562               Isis  Female         -                  -              -
# 563             Dagger  Female      blue                  -          Blond
# 564           Galactus    Male     black      Cosmic Entity          Black
# 565           Namorita  Female      blue                  -          Blond
# 566           Scorpion    Male     brown              Human          Brown
# 567           Evilhawk    Male       red              Alien          Black
# 568    Green Goblin II    Male      blue                  -         Auburn
# 569    Invisible Woman  Female      blue  Human / Radiation          Blond
# 570              Siren  Female      blue          Atlantean         Purple
# 571          Agent Bob    Male     brown              Human          Brown
# 572         Spider-Man       -       red              Human          Brown
# 573              Joker    Male     green              Human          Green
# 574           Robin II    Male      blue              Human            Red
# 575              Beast    Male      blue             Mutant           Blue
# 576             Azazel    Male    yellow           Neyaphem          Black
# 577          Atom Girl  Female     black                  -          Black
# 578           Mephisto    Male     white                  -          Black
# 579              Robin    Male      blue              Human          Black
# 580           Firebird  Female     brown                  -          Black
# 581  Kraven the Hunter    Male     brown              Human          Black
# 582          Offspring    Male         -                  -              -
# 583          Weapon XI    Male         -                  -              -
# 584             Box IV       -     brown                  -  Brown / Black
# 585       Black Canary  Female      blue          Metahuman          Blond
# 586        Quicksilver    Male      blue             Mutant         Silver
# 587             Speedy  Female     green              Human          Brown
# 588            Tempest  Female     brown                  -          Black
#
#      Height      Publisher Skin_color Alignment  Weight    ...      \
# 0     196.0  Marvel Comics          -       bad   248.0    ...
# 1     -99.0      DC Comics       blue       bad   -99.0    ...
# 2     165.0      DC Comics          -   neutral    50.0    ...
# 3     168.0       Shueisha          -       bad    73.0    ...
# 4     -99.0      DC Comics          -       bad   -99.0    ...
# 5     -99.0   Image Comics          -       bad   -99.0    ...
# 6     175.0      DC Comics          -      good    74.0    ...
# 7     -99.0  Marvel Comics          -       bad   -99.0    ...
# 8     188.0  Marvel Comics          -   neutral    87.0    ...
# 9     -99.0   George Lucas          -       bad   -99.0    ...
# 10    180.0      DC Comics          -      good    81.0    ...
# 11    180.0  Marvel Comics          -       bad    90.0    ...
# 12    178.0  Marvel Comics          -      good    49.0    ...
# 13    180.0  Marvel Comics          -       bad    79.0    ...
# 14    185.0  Marvel Comics       grey       bad   203.0    ...
# 15    211.0  Marvel Comics          -      good   122.0    ...
# 16    -99.0   Image Comics          -       bad   -99.0    ...
# 17    -99.0      DC Comics          -      good   -99.0    ...
# 18    170.0      DC Comics          -      good    59.0    ...
# 19    198.0  Marvel Comics          -      good   288.0    ...
# 20    183.0  Marvel Comics          -      good    90.0    ...
# 21    183.0      DC Comics          -      good    81.0    ...
# 22    163.0  Marvel Comics          -      good    56.0    ...
# 23    180.0  Marvel Comics          -      good    72.0    ...
# 24    180.0      DC Comics          -       bad    72.0    ...
# 25    213.0   George Lucas       gray      good   -99.0    ...
# 26    185.0      DC Comics          -      good   146.0    ...
# 27    170.0  Marvel Comics          -      good   -99.0    ...
# 28    188.0  Marvel Comics          -       bad   108.0    ...
# 29    198.0      DC Comics          -      good   173.0    ...
# ..      ...            ...        ...       ...     ...    ...
# 559   193.0  Marvel Comics          -      good    99.0    ...
# 560   -99.0      DC Comics          -      good   -99.0    ...
# 561   -99.0   NBC - Heroes          -      good   -99.0    ...
# 562   -99.0      DC Comics          -      good   -99.0    ...
# 563   165.0  Marvel Comics          -      good    52.0    ...
# 564   876.0  Marvel Comics          -   neutral    16.0    ...
# 565   168.0  Marvel Comics          -      good   101.0    ...
# 566   211.0  Marvel Comics          -       bad   310.0    ...
# 567   191.0  Marvel Comics      green       bad   106.0    ...
# 568   178.0  Marvel Comics          -       bad    77.0    ...
# 569   168.0  Marvel Comics          -      good    54.0    ...
# 570   175.0      DC Comics          -       bad    72.0    ...
# 571   178.0  Marvel Comics          -      good    81.0    ...
# 572   178.0  Marvel Comics          -      good    77.0    ...
# 573   196.0      DC Comics      white       bad    86.0    ...
# 574   183.0      DC Comics          -      good   101.0    ...
# 575   180.0  Marvel Comics       blue      good   181.0    ...
# 576   183.0  Marvel Comics        red       bad    67.0    ...
# 577   168.0      DC Comics          -      good    54.0    ...
# 578   198.0  Marvel Comics          -       bad   140.0    ...
# 579   178.0      DC Comics          -      good    79.0    ...
# 580   165.0  Marvel Comics          -      good    56.0    ...
# 581   183.0  Marvel Comics          -       bad   106.0    ...
# 582   -99.0      DC Comics          -      good   -99.0    ...
# 583   -99.0  Marvel Comics          -       bad   -99.0    ...
# 584   -99.0  Marvel Comics          -      good   -99.0    ...
# 585   170.0      DC Comics          -      good    59.0    ...
# 586   183.0  Marvel Comics          -      good    79.0    ...
# 587   -99.0      DC Comics          -      good   -99.0    ...
# 588   163.0  Marvel Comics          -      good    54.0    ...
#
#     Web_Creation Reality_Warping Odin_Force Symbiote_Costume Speed_Force  \
# 0          FALSE           FALSE      FALSE            FALSE       FALSE
# 1          FALSE           FALSE      FALSE            FALSE       FALSE
# 2          FALSE           FALSE      FALSE            FALSE       FALSE
# 3          FALSE           FALSE      FALSE            FALSE       FALSE
# 4          FALSE           FALSE      FALSE            FALSE       FALSE
# 5          FALSE           FALSE      FALSE            FALSE       FALSE
# 6          FALSE           FALSE      FALSE            FALSE       FALSE
# 7          FALSE           FALSE      FALSE            FALSE       FALSE
# 8          FALSE           FALSE      FALSE            FALSE       FALSE
# 9          FALSE           FALSE      FALSE            FALSE       FALSE
# 10         FALSE           FALSE      FALSE            FALSE       FALSE
# 11         FALSE           FALSE      FALSE            FALSE       FALSE
# 12         FALSE           FALSE      FALSE            FALSE       FALSE
# 13         FALSE           FALSE      FALSE            FALSE       FALSE
# 14         FALSE           FALSE      FALSE            FALSE       FALSE
# 15         FALSE           FALSE      FALSE            FALSE       FALSE
# 16         FALSE           FALSE      FALSE            FALSE       FALSE
# 17         FALSE           FALSE      FALSE            FALSE       FALSE
# 18         FALSE           FALSE      FALSE            FALSE       FALSE
# 19         FALSE           FALSE       TRUE            FALSE       FALSE
# 20         FALSE           FALSE      FALSE            FALSE       FALSE
# 21         FALSE           FALSE      FALSE            FALSE       FALSE
# 22         FALSE           FALSE      FALSE            FALSE       FALSE
# 23         FALSE           FALSE      FALSE            FALSE       FALSE
# 24         FALSE           FALSE      FALSE            FALSE       FALSE
# 25         FALSE           FALSE      FALSE            FALSE       FALSE
# 26         FALSE           FALSE      FALSE            FALSE       FALSE
# 27         FALSE           FALSE      FALSE            FALSE       FALSE
# 28         FALSE           FALSE      FALSE            FALSE       FALSE
# 29         FALSE           FALSE      FALSE            FALSE       FALSE
# ..           ...             ...        ...              ...         ...
# 559        FALSE           FALSE      FALSE            FALSE       FALSE
# 560        FALSE           FALSE      FALSE            FALSE       FALSE
# 561        FALSE           FALSE      FALSE            FALSE       FALSE
# 562        FALSE           FALSE      FALSE            FALSE       FALSE
# 563        FALSE           FALSE      FALSE            FALSE       FALSE
# 564        FALSE           FALSE      FALSE            FALSE       FALSE
# 565        FALSE           FALSE      FALSE            FALSE       FALSE
# 566        FALSE           FALSE      FALSE            FALSE       FALSE
# 567        FALSE           FALSE      FALSE            FALSE       FALSE
# 568        FALSE           FALSE      FALSE            FALSE       FALSE
# 569        FALSE           FALSE      FALSE            FALSE       FALSE
# 570        FALSE           FALSE      FALSE            FALSE       FALSE
# 571        FALSE           FALSE      FALSE            FALSE       FALSE
# 572         TRUE           FALSE      FALSE            FALSE       FALSE
# 573        FALSE           FALSE      FALSE            FALSE       FALSE
# 574        FALSE           FALSE      FALSE            FALSE       FALSE
# 575        FALSE           FALSE      FALSE            FALSE       FALSE
# 576        FALSE           FALSE      FALSE            FALSE       FALSE
# 577        FALSE           FALSE      FALSE            FALSE       FALSE
# 578        FALSE           FALSE      FALSE            FALSE       FALSE
# 579        FALSE           FALSE      FALSE            FALSE       FALSE
# 580        FALSE           FALSE      FALSE            FALSE       FALSE
# 581        FALSE           FALSE      FALSE            FALSE       FALSE
# 582        FALSE           FALSE      FALSE            FALSE       FALSE
# 583        FALSE           FALSE      FALSE            FALSE       FALSE
# 584        FALSE           FALSE      FALSE            FALSE       FALSE
# 585        FALSE           FALSE      FALSE            FALSE       FALSE
# 586        FALSE           FALSE      FALSE            FALSE       FALSE
# 587        FALSE           FALSE      FALSE            FALSE       FALSE
# 588        FALSE           FALSE      FALSE            FALSE       FALSE
#
#     Phoenix_Force Molecular_Dissipation Vision_Cryo Omnipresent Omniscient
# 0           FALSE                 FALSE       FALSE       FALSE      FALSE
# 1           FALSE                 FALSE       FALSE       FALSE      FALSE
# 2           FALSE                 FALSE       FALSE       FALSE      FALSE
# 3           FALSE                 FALSE       FALSE       FALSE      FALSE
# 4           FALSE                 FALSE       FALSE       FALSE      FALSE
# 5           FALSE                 FALSE       FALSE       FALSE      FALSE
# 6           FALSE                 FALSE       FALSE       FALSE      FALSE
# 7           FALSE                 FALSE       FALSE       FALSE      FALSE
# 8           FALSE                 FALSE       FALSE       FALSE      FALSE
# 9           FALSE                 FALSE       FALSE       FALSE      FALSE
# 10          FALSE                 FALSE       FALSE       FALSE      FALSE
# 11          FALSE                 FALSE       FALSE       FALSE      FALSE
# 12          FALSE                 FALSE       FALSE       FALSE      FALSE
# 13          FALSE                 FALSE       FALSE       FALSE      FALSE
# 14          FALSE                 FALSE       FALSE       FALSE      FALSE
# 15          FALSE                 FALSE       FALSE       FALSE      FALSE
# 16          FALSE                 FALSE       FALSE       FALSE      FALSE
# 17          FALSE                 FALSE       FALSE       FALSE      FALSE
# 18          FALSE                 FALSE       FALSE       FALSE      FALSE
# 19          FALSE                 FALSE       FALSE       FALSE      FALSE
# 20          FALSE                 FALSE       FALSE       FALSE      FALSE
# 21          FALSE                 FALSE       FALSE       FALSE      FALSE
# 22          FALSE                 FALSE       FALSE       FALSE      FALSE
# 23          FALSE                 FALSE       FALSE       FALSE      FALSE
# 24          FALSE                 FALSE       FALSE       FALSE      FALSE
# 25          FALSE                 FALSE       FALSE       FALSE      FALSE
# 26          FALSE                 FALSE       FALSE       FALSE      FALSE
# 27          FALSE                 FALSE       FALSE       FALSE      FALSE
# 28          FALSE                 FALSE       FALSE       FALSE      FALSE
# 29          FALSE                 FALSE       FALSE       FALSE      FALSE
# ..            ...                   ...         ...         ...        ...
# 559         FALSE                 FALSE       FALSE       FALSE      FALSE
# 560         FALSE                 FALSE       FALSE       FALSE      FALSE
# 561         FALSE                 FALSE       FALSE       FALSE      FALSE
# 562         FALSE                 FALSE       FALSE       FALSE      FALSE
# 563         FALSE                 FALSE       FALSE       FALSE      FALSE
# 564         FALSE                 FALSE       FALSE       FALSE      FALSE
# 565         FALSE                 FALSE       FALSE       FALSE      FALSE
# 566         FALSE                 FALSE       FALSE       FALSE      FALSE
# 567         FALSE                 FALSE       FALSE       FALSE      FALSE
# 568         FALSE                 FALSE       FALSE       FALSE      FALSE
# 569         FALSE                 FALSE       FALSE       FALSE      FALSE
# 570         FALSE                 FALSE       FALSE       FALSE      FALSE
# 571         FALSE                 FALSE       FALSE       FALSE      FALSE
# 572         FALSE                 FALSE       FALSE       FALSE      FALSE
# 573         FALSE                 FALSE       FALSE       FALSE      FALSE
# 574         FALSE                 FALSE       FALSE       FALSE      FALSE
# 575         FALSE                 FALSE       FALSE       FALSE      FALSE
# 576         FALSE                 FALSE       FALSE       FALSE      FALSE
# 577         FALSE                 FALSE       FALSE       FALSE      FALSE
# 578         FALSE                 FALSE       FALSE       FALSE      FALSE
# 579         FALSE                 FALSE       FALSE       FALSE      FALSE
# 580         FALSE                 FALSE       FALSE       FALSE      FALSE
# 581         FALSE                 FALSE       FALSE       FALSE      FALSE
# 582         FALSE                 FALSE       FALSE       FALSE      FALSE
# 583         FALSE                 FALSE       FALSE       FALSE      FALSE
# 584         FALSE                 FALSE       FALSE       FALSE      FALSE
# 585         FALSE                 FALSE       FALSE       FALSE      FALSE
# 586         FALSE                 FALSE       FALSE       FALSE      FALSE
# 587         FALSE                 FALSE       FALSE       FALSE      FALSE
# 588         FALSE                 FALSE       FALSE       FALSE      FALSE
#
# [589 rows x 177 columns]

# %%
with open_file(EVALSET_CSV, "r") as f:
    df_eval = pd.read_csv(f)
for c in df_eval.columns:
    if df_eval[c].dtypes.name == 'bool':
        df_eval[c]=df_eval[c].map({True: 'TRUE', False: 'FALSE'})
df_eval
# Out:
#                index  Gender                Eye_color               Race  \
# 0            Phantom    Male                        -                  -
# 1      Absorbing Man    Male                     blue              Human
# 2           Deadshot    Male                    brown              Human
# 3         Hal Jordan    Male                    brown              Human
# 4        Black Flash    Male                        -      God / Eternal
# 5            Zatanna  Female                     blue              Human
# 6    Captain America    Male                     blue              Human
# 7       Captain Epic    Male                     blue                  -
# 8            Vulture    Male                    brown              Human
# 9           Hyperion    Male                     blue            Eternal
# 10           Robin V    Male                     blue              Human
# 11           Jubilee  Female                      red             Mutant
# 12       Guy Gardner    Male                     blue    Human-Vuldarian
# 13      Wonder Woman  Female                     blue             Amazon
# 14   Silk Spectre II  Female                        -                  -
# 15           Chromos    Male                    brown                  -
# 16            Bling!  Female                        -                  -
# 17              Luna  Female                        -              Human
# 18           Genesis    Male                     blue                  -
# 19             Feral       -  yellow (without irises)                  -
# 20              Hela  Female                    green          Asgardian
# 21    Captain Marvel  Female                     blue         Human-Kree
# 22         Gladiator    Male                     blue          Strontian
# 23        Donna Troy  Female                     blue             Amazon
# 24        Cannonball    Male                     blue                  -
# 25      Bionic Woman  Female                     blue             Cyborg
# 26            Ardina  Female                    white              Alien
# 27      Stormtrooper    Male                        -              Human
# 28    Doctor Strange    Male                     grey              Human
# 29               Cat  Female                     blue                  -
# ..               ...     ...                      ...                ...
# 34          Blizzard    Male                        -                  -
# 35       Bill Harken    Male                        -              Alpha
# 36      Minna Murray  Female                        -                  -
# 37    Peter Petrelli    Male                        -                  -
# 38              Bane    Male                        -              Human
# 39           Gravity    Male                     blue              Human
# 40    Solomon Grundy    Male                    black             Zombie
# 41       Swamp Thing    Male                      red      God / Eternal
# 42     One Punch Man    Male                        -              Human
# 43             Armor  Female                    black                  -
# 44          Flash II    Male                     blue              Human
# 45              Wasp  Female                     blue              Human
# 46       Liz Sherman  Female                        -                  -
# 47            Oracle  Female                     blue              Human
# 48  Katniss Everdeen  Female                        -              Human
# 49         She-Thing  Female                     blue  Human / Radiation
# 50       Professor X    Male                     blue             Mutant
# 51        Sabretooth    Male                    amber             Mutant
# 52    Blue Beetle II    Male                     blue                  -
# 53        Demogoblin    Male                      red              Demon
# 54         Moonstone  Female                     blue                  -
# 55    Rocket Raccoon    Male                    brown             Animal
# 56             Swarm    Male                   yellow             Mutant
# 57              Ammo    Male                    brown              Human
# 58              Ymir    Male                    white        Frost Giant
# 59          Punisher    Male                     blue              Human
# 60     Indiana Jones    Male                        -              Human
# 61      Living Brain       -                   yellow                  -
# 62         Rick Flag    Male                     blue                  -
# 63            Falcon    Male                    brown              Human
#
#         Hair_color  Height          Publisher Skin_color Alignment  Weight  \
# 0                -   -99.0          DC Comics          -      good   -99.0
# 1          No Hair   193.0      Marvel Comics          -       bad   122.0
# 2            Brown   185.0          DC Comics          -       bad    91.0
# 3            Brown   188.0          DC Comics          -      good    90.0
# 4                -   -99.0          DC Comics          -   neutral   -99.0
# 5            Black   170.0          DC Comics          -      good    57.0
# 6            blond   188.0      Marvel Comics          -      good   108.0
# 7            Brown   188.0       Team Epic TV          -      good   -99.0
# 8          No Hair   180.0      Marvel Comics          -       bad    79.0
# 9              Red   183.0      Marvel Comics          -      good   207.0
# 10           Black   137.0          DC Comics          -      good    38.0
# 11           Black   165.0      Marvel Comics          -      good    52.0
# 12             Red   188.0          DC Comics          -      good    95.0
# 13           Black   183.0          DC Comics          -      good    74.0
# 14               -   -99.0          DC Comics          -      good   -99.0
# 15      Red / Grey   185.0       Team Epic TV          -       bad    86.0
# 16               -   168.0      Marvel Comics          -      good    68.0
# 17               -   -99.0      Marvel Comics          -      good   -99.0
# 18           Blond   185.0      Marvel Comics          -      good    86.0
# 19  Orange / White   175.0      Marvel Comics          -      good    50.0
# 20           Black   213.0      Marvel Comics          -       bad   225.0
# 21           Blond   180.0      Marvel Comics          -      good    74.0
# 22            Blue   198.0      Marvel Comics     purple   neutral   268.0
# 23           Black   175.0          DC Comics          -      good    63.0
# 24           Blond   183.0      Marvel Comics          -      good    81.0
# 25           Black   -99.0                NaN          -      good   -99.0
# 26          Orange   193.0      Marvel Comics       gold      good    98.0
# 27               -   183.0       George Lucas          -       bad   -99.0
# 28           Black   188.0      Marvel Comics          -      good    81.0
# 29           Blond   173.0      Marvel Comics          -      good    61.0
# ..             ...     ...                ...        ...       ...     ...
# 34               -   -99.0      Marvel Comics          -       bad   -99.0
# 35               -   -99.0               SyFy          -      good   -99.0
# 36               -   -99.0          Wildstorm          -      good   -99.0
# 37               -   -99.0       NBC - Heroes          -      good   -99.0
# 38               -   203.0          DC Comics          -       bad   180.0
# 39           Brown   178.0      Marvel Comics          -      good    79.0
# 40           White   279.0          DC Comics          -       bad   437.0
# 41         No Hair   -99.0          DC Comics      green       bad   -99.0
# 42         No Hair   175.0           Shueisha          -      good    69.0
# 43           Black   163.0      Marvel Comics          -      good    50.0
# 44           Blond   183.0          DC Comics          -      good    88.0
# 45          Auburn   163.0      Marvel Comics          -      good    50.0
# 46               -   -99.0  Dark Horse Comics          -      good   -99.0
# 47             Red   178.0          DC Comics          -      good    59.0
# 48               -   -99.0                NaN          -      good   -99.0
# 49         No Hair   183.0      Marvel Comics          -      good   153.0
# 50         No Hair   183.0      Marvel Comics          -      good    86.0
# 51           Blond   198.0      Marvel Comics          -       bad   171.0
# 52           Brown   183.0          DC Comics          -      good    86.0
# 53         No Hair   185.0      Marvel Comics          -       bad    95.0
# 54           Blond   180.0      Marvel Comics          -       bad    59.0
# 55           Brown   122.0      Marvel Comics          -      good    25.0
# 56         No Hair   196.0      Marvel Comics     yellow       bad    47.0
# 57           Black   188.0      Marvel Comics          -       bad   101.0
# 58         No Hair   304.8      Marvel Comics      white      good   -99.0
# 59           Black   183.0      Marvel Comics          -      good    90.0
# 60               -   183.0       George Lucas          -      good    79.0
# 61               -   198.0      Marvel Comics          -       bad   360.0
# 62           Brown   185.0          DC Comics          -       bad    85.0
# 63           Black   188.0      Marvel Comics          -      good   108.0
#
#       ...     Web_Creation Reality_Warping Odin_Force Symbiote_Costume  \
# 0     ...            FALSE           FALSE      FALSE            FALSE
# 1     ...            FALSE           FALSE      FALSE            FALSE
# 2     ...            FALSE           FALSE      FALSE            FALSE
# 3     ...            FALSE           FALSE      FALSE            FALSE
# 4     ...            FALSE           FALSE      FALSE            FALSE
# 5     ...            FALSE           FALSE      FALSE            FALSE
# 6     ...            FALSE           FALSE      FALSE            FALSE
# 7     ...            FALSE           FALSE      FALSE            FALSE
# 8     ...            FALSE           FALSE      FALSE            FALSE
# 9     ...            FALSE           FALSE      FALSE            FALSE
# 10    ...            FALSE           FALSE      FALSE            FALSE
# 11    ...            FALSE           FALSE      FALSE            FALSE
# 12    ...            FALSE           FALSE      FALSE            FALSE
# 13    ...            FALSE           FALSE      FALSE            FALSE
# 14    ...            FALSE           FALSE      FALSE            FALSE
# 15    ...            FALSE           FALSE      FALSE            FALSE
# 16    ...            FALSE           FALSE      FALSE            FALSE
# 17    ...            FALSE           FALSE      FALSE            FALSE
# 18    ...            FALSE           FALSE      FALSE            FALSE
# 19    ...            FALSE           FALSE      FALSE            FALSE
# 20    ...            FALSE           FALSE      FALSE            FALSE
# 21    ...            FALSE           FALSE      FALSE            FALSE
# 22    ...            FALSE           FALSE      FALSE            FALSE
# 23    ...            FALSE           FALSE      FALSE            FALSE
# 24    ...            FALSE           FALSE      FALSE            FALSE
# 25    ...            FALSE           FALSE      FALSE            FALSE
# 26    ...            FALSE           FALSE      FALSE            FALSE
# 27    ...            FALSE           FALSE      FALSE            FALSE
# 28    ...            FALSE           FALSE      FALSE            FALSE
# 29    ...            FALSE           FALSE      FALSE            FALSE
# ..    ...              ...             ...        ...              ...
# 34    ...            FALSE           FALSE      FALSE            FALSE
# 35    ...            FALSE           FALSE      FALSE            FALSE
# 36    ...            FALSE           FALSE      FALSE            FALSE
# 37    ...            FALSE           FALSE      FALSE            FALSE
# 38    ...            FALSE           FALSE      FALSE            FALSE
# 39    ...            FALSE           FALSE      FALSE            FALSE
# 40    ...            FALSE           FALSE      FALSE            FALSE
# 41    ...            FALSE           FALSE      FALSE            FALSE
# 42    ...            FALSE           FALSE      FALSE            FALSE
# 43    ...            FALSE           FALSE      FALSE            FALSE
# 44    ...            FALSE           FALSE      FALSE            FALSE
# 45    ...            FALSE           FALSE      FALSE            FALSE
# 46    ...            FALSE           FALSE      FALSE            FALSE
# 47    ...            FALSE           FALSE      FALSE            FALSE
# 48    ...            FALSE           FALSE      FALSE            FALSE
# 49    ...            FALSE           FALSE      FALSE            FALSE
# 50    ...            FALSE           FALSE      FALSE            FALSE
# 51    ...            FALSE           FALSE      FALSE            FALSE
# 52    ...            FALSE           FALSE      FALSE            FALSE
# 53    ...            FALSE           FALSE      FALSE            FALSE
# 54    ...            FALSE           FALSE      FALSE            FALSE
# 55    ...            FALSE           FALSE      FALSE            FALSE
# 56    ...            FALSE           FALSE      FALSE            FALSE
# 57    ...            FALSE           FALSE      FALSE            FALSE
# 58    ...            FALSE           FALSE      FALSE            FALSE
# 59    ...            FALSE           FALSE      FALSE            FALSE
# 60    ...            FALSE           FALSE      FALSE            FALSE
# 61    ...            FALSE           FALSE      FALSE            FALSE
# 62    ...            FALSE           FALSE      FALSE            FALSE
# 63    ...            FALSE           FALSE      FALSE            FALSE
#
#    Speed_Force Phoenix_Force Molecular_Dissipation Vision_Cryo Omnipresent  \
# 0        FALSE         FALSE                 FALSE       FALSE       FALSE
# 1        FALSE         FALSE                 FALSE       FALSE       FALSE
# 2        FALSE         FALSE                 FALSE       FALSE       FALSE
# 3        FALSE         FALSE                 FALSE       FALSE       FALSE
# 4        FALSE         FALSE                 FALSE       FALSE       FALSE
# 5        FALSE         FALSE                 FALSE       FALSE       FALSE
# 6        FALSE         FALSE                 FALSE       FALSE       FALSE
# 7        FALSE         FALSE                 FALSE       FALSE       FALSE
# 8        FALSE         FALSE                 FALSE       FALSE       FALSE
# 9        FALSE         FALSE                 FALSE       FALSE       FALSE
# 10       FALSE         FALSE                 FALSE       FALSE       FALSE
# 11       FALSE         FALSE                 FALSE       FALSE       FALSE
# 12       FALSE         FALSE                 FALSE       FALSE       FALSE
# 13       FALSE         FALSE                 FALSE       FALSE       FALSE
# 14       FALSE         FALSE                 FALSE       FALSE       FALSE
# 15       FALSE         FALSE                 FALSE       FALSE       FALSE
# 16       FALSE         FALSE                 FALSE       FALSE       FALSE
# 17       FALSE         FALSE                 FALSE       FALSE       FALSE
# 18       FALSE         FALSE                 FALSE       FALSE       FALSE
# 19       FALSE         FALSE                 FALSE       FALSE       FALSE
# 20       FALSE         FALSE                 FALSE       FALSE       FALSE
# 21       FALSE         FALSE                 FALSE       FALSE       FALSE
# 22       FALSE         FALSE                 FALSE       FALSE       FALSE
# 23       FALSE         FALSE                 FALSE       FALSE       FALSE
# 24       FALSE         FALSE                 FALSE       FALSE       FALSE
# 25       FALSE         FALSE                 FALSE       FALSE       FALSE
# 26       FALSE         FALSE                 FALSE       FALSE       FALSE
# 27       FALSE         FALSE                 FALSE       FALSE       FALSE
# 28       FALSE         FALSE                 FALSE       FALSE       FALSE
# 29       FALSE         FALSE                 FALSE       FALSE       FALSE
# ..         ...           ...                   ...         ...         ...
# 34       FALSE         FALSE                 FALSE       FALSE       FALSE
# 35       FALSE         FALSE                 FALSE       FALSE       FALSE
# 36       FALSE         FALSE                 FALSE       FALSE       FALSE
# 37       FALSE         FALSE                 FALSE       FALSE       FALSE
# 38       FALSE         FALSE                 FALSE       FALSE       FALSE
# 39       FALSE         FALSE                 FALSE       FALSE       FALSE
# 40       FALSE         FALSE                 FALSE       FALSE       FALSE
# 41       FALSE         FALSE                 FALSE       FALSE       FALSE
# 42       FALSE         FALSE                 FALSE       FALSE       FALSE
# 43       FALSE         FALSE                 FALSE       FALSE       FALSE
# 44        TRUE         FALSE                 FALSE       FALSE       FALSE
# 45       FALSE         FALSE                 FALSE       FALSE       FALSE
# 46       FALSE         FALSE                 FALSE       FALSE       FALSE
# 47       FALSE         FALSE                 FALSE       FALSE       FALSE
# 48       FALSE         FALSE                 FALSE       FALSE       FALSE
# 49       FALSE         FALSE                 FALSE       FALSE       FALSE
# 50       FALSE         FALSE                 FALSE       FALSE       FALSE
# 51       FALSE         FALSE                 FALSE       FALSE       FALSE
# 52       FALSE         FALSE                 FALSE       FALSE       FALSE
# 53       FALSE         FALSE                 FALSE       FALSE       FALSE
# 54       FALSE         FALSE                 FALSE       FALSE       FALSE
# 55       FALSE         FALSE                 FALSE       FALSE       FALSE
# 56       FALSE         FALSE                 FALSE       FALSE       FALSE
# 57       FALSE         FALSE                 FALSE       FALSE       FALSE
# 58       FALSE         FALSE                 FALSE       FALSE       FALSE
# 59       FALSE         FALSE                 FALSE       FALSE       FALSE
# 60       FALSE         FALSE                 FALSE       FALSE       FALSE
# 61       FALSE         FALSE                 FALSE       FALSE       FALSE
# 62       FALSE         FALSE                 FALSE       FALSE       FALSE
# 63       FALSE         FALSE                 FALSE       FALSE       FALSE
#
#    Omniscient
# 0       FALSE
# 1       FALSE
# 2       FALSE
# 3       FALSE
# 4       FALSE
# 5       FALSE
# 6       FALSE
# 7       FALSE
# 8       FALSE
# 9       FALSE
# 10      FALSE
# 11      FALSE
# 12      FALSE
# 13      FALSE
# 14      FALSE
# 15      FALSE
# 16      FALSE
# 17      FALSE
# 18      FALSE
# 19      FALSE
# 20      FALSE
# 21      FALSE
# 22      FALSE
# 23      FALSE
# 24      FALSE
# 25      FALSE
# 26      FALSE
# 27      FALSE
# 28      FALSE
# 29      FALSE
# ..        ...
# 34      FALSE
# 35      FALSE
# 36      FALSE
# 37      FALSE
# 38      FALSE
# 39      FALSE
# 40      FALSE
# 41      FALSE
# 42      FALSE
# 43      FALSE
# 44      FALSE
# 45      FALSE
# 46      FALSE
# 47      FALSE
# 48      FALSE
# 49      FALSE
# 50      FALSE
# 51      FALSE
# 52      FALSE
# 53      FALSE
# 54      FALSE
# 55      FALSE
# 56      FALSE
# 57      FALSE
# 58      FALSE
# 59      FALSE
# 60      FALSE
# 61      FALSE
# 62      FALSE
# 63      FALSE
#
# [64 rows x 177 columns]

# %%
with open_file(os.path.join(MODEL_DIR,"trainset.csv"), "w") as f:
    df.to_csv(f,index=False)
with open_file(os.path.join(MODEL_DIR,"evalset.csv"), "w") as f:
    df_eval.to_csv(f,index=False)

# %%
exclude_columns=["Publisher","Height","Weight","Skin_color","Race"]
INDEX=df.columns[0]
COLUMNS=[x for x in df.columns[1:] if x not in exclude_columns]
LABEL_FIELD="Alignment"

# %% [markdown]
# # TRAINING

# %% [markdown]
# ### Gather all the required informations from the dataset

# %%
FIELD_DEFAULTS=[]
FIELD_TYPES={}
FIELD_CATEGORIES={}
dtypes=dict(df.dtypes)
for c in COLUMNS:
    if(str(dtypes[c])=="bool"):
        FIELD_DEFAULTS.append([0])
        FIELD_TYPES[c]="bool"
    elif(str(dtypes[c])=="object"):
        FIELD_DEFAULTS.append(["NA"])
        FIELD_TYPES[c]="string"
        FIELD_CATEGORIES[c]=list(sorted(set(list(df[c].unique())+["NA"])))
    else:  
        FIELD_DEFAULTS.append([0.0])
        FIELD_TYPES[c]="number"
FIELD_CATEGORIES[LABEL_FIELD]=[x for x in FIELD_CATEGORIES[LABEL_FIELD] if x != "NA"]

# %% [markdown]
# ### Save dataset informations

# %%
#if(not os.path.isdir(MODEL_DIR)):
#    os.makedirs(MODEL_DIR)

with open_file(os.path.join(MODEL_DIR,"data","dataset_fields.json"), "w") as f:
    json.dump(
        {
            "fields":{
                "columns" : [x for x in COLUMNS if x != LABEL_FIELD],
                "types" : {x:FIELD_TYPES[x] for x in FIELD_TYPES if x != LABEL_FIELD},
                "categories" : {x:FIELD_CATEGORIES[x] for x in FIELD_CATEGORIES if x != LABEL_FIELD}
            },
            "label":{
                "column" : LABEL_FIELD,
                "type" : FIELD_TYPES[LABEL_FIELD],
                "categories" : FIELD_CATEGORIES[LABEL_FIELD],
            }
        },
        f
    )

# %% [markdown]
# ### Create a dataset object

# %%
with open_file(os.path.join(MODEL_DIR,"data","actual_trainset.csv"), "w") as f:
    df[[INDEX]+COLUMNS].to_csv(f, index=False)
with open_file(os.path.join(MODEL_DIR,"data","actual_evalset.csv"), "w") as f:
    df_eval[[INDEX]+COLUMNS].to_csv(f, index=False)

# %%
#tf.reset_default_graph()
with open_file(os.path.join(MODEL_DIR,"data","tf_trainset.csv"), "w") as f:
    df[COLUMNS].to_csv(f, index=False)

def create_trainset():
    ds = tf.data.TextLineDataset(os.path.join(MODEL_DIR,"data","tf_trainset.csv")).skip(1)
    def _parse_line(line):
        # Decode the line into its fields
        fields = tf.decode_csv(line, FIELD_DEFAULTS)

        # Pack the result into a dictionary
        features = dict(zip(COLUMNS,fields))

        # Separate the label from the features
        label = features.pop(LABEL_FIELD)

        return features, label

    parsed_ds = ds.map(_parse_line)
    
    return parsed_ds.shuffle(TRAIN_STEPS).repeat().batch(BATCH_SIZE)




with open_file(os.path.join(MODEL_DIR,"data","tf_evalset.csv"), "w") as f:
    df_eval[COLUMNS].to_csv(f, index=False)

def create_evalset():
    ds = tf.data.TextLineDataset(os.path.join(MODEL_DIR,"data","tf_evalset.csv")).skip(1)
    def _parse_line(line):
        # Decode the line into its fields
        fields = tf.decode_csv(line, FIELD_DEFAULTS)

        # Pack the result into a dictionary
        features = dict(zip(COLUMNS,fields))

        # Separate the label from the features
        label = features.pop(LABEL_FIELD)

        return features, label

    parsed_ds = ds.map(_parse_line)
    
    return parsed_ds.shuffle(TRAIN_STEPS).repeat().batch(BATCH_SIZE)

# %% [markdown]
# ### build and train the estimator

# %%
print(list(FIELD_CATEGORIES[LABEL_FIELD]))
feature_columns=[]
for c in COLUMNS:
    if c == LABEL_FIELD:
        continue
        
    if FIELD_TYPES[c]=="string":
        feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(
                key=c,
                vocabulary_list=list(FIELD_CATEGORIES[c])
            ))
    if FIELD_TYPES[c]=="number":
        feature_columns.append(tf.feature_column.numeric_column(key=c))
        
est = tf.estimator.LinearClassifier(
    feature_columns,
    n_classes=len(FIELD_CATEGORIES[LABEL_FIELD]),
    label_vocabulary=list(FIELD_CATEGORIES[LABEL_FIELD]),
    model_dir=MODEL_DIR
)
# Train the estimator
#est.train(
#    steps=TRAIN_STEPS,
#    input_fn=create_dataset)

# Train and evaluate the estimator
tf.estimator.train_and_evaluate(
    est,
    tf.estimator.TrainSpec(input_fn=create_trainset, max_steps=TRAIN_STEPS),
    tf.estimator.EvalSpec(input_fn=create_evalset)
)
# Out:
# ['bad', 'good', 'neutral']
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fee7e0c8750>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': 'gs://ml-research-injenia/estimators/trainings/linear-classifier/test08', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-44786
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 44787 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:loss = 22.713335, step = 44787
# INFO:tensorflow:global_step/sec: 7.41571
# INFO:tensorflow:loss = 21.699379, step = 44887 (13.485 sec)
# INFO:tensorflow:global_step/sec: 19.7107
# INFO:tensorflow:loss = 28.58156, step = 44987 (5.073 sec)
# INFO:tensorflow:global_step/sec: 20.2441
# INFO:tensorflow:loss = 24.452206, step = 45087 (4.940 sec)
# INFO:tensorflow:global_step/sec: 20.1823
# INFO:tensorflow:loss = 30.295197, step = 45187 (4.955 sec)
# INFO:tensorflow:global_step/sec: 20.1759
# INFO:tensorflow:loss = 22.373907, step = 45287 (4.957 sec)
# INFO:tensorflow:global_step/sec: 20.0383
# INFO:tensorflow:loss = 23.198307, step = 45387 (4.991 sec)
# INFO:tensorflow:global_step/sec: 20.4255
# INFO:tensorflow:loss = 25.997297, step = 45487 (4.895 sec)
# INFO:tensorflow:global_step/sec: 20.582
# INFO:tensorflow:loss = 30.94345, step = 45587 (4.859 sec)
# INFO:tensorflow:global_step/sec: 20.1079
# INFO:tensorflow:loss = 20.57466, step = 45687 (4.973 sec)
# INFO:tensorflow:global_step/sec: 19.7809
# INFO:tensorflow:loss = 33.782394, step = 45787 (5.056 sec)
# INFO:tensorflow:global_step/sec: 20.5741
# INFO:tensorflow:loss = 30.341393, step = 45887 (4.861 sec)
# INFO:tensorflow:global_step/sec: 20.5138
# INFO:tensorflow:loss = 34.645298, step = 45987 (4.874 sec)
# INFO:tensorflow:global_step/sec: 20.2485
# INFO:tensorflow:loss = 35.536686, step = 46087 (6.072 sec)
# INFO:tensorflow:global_step/sec: 16.3643
# INFO:tensorflow:loss = 23.72953, step = 46187 (4.978 sec)
# INFO:tensorflow:global_step/sec: 20.5582
# INFO:tensorflow:loss = 20.064627, step = 46287 (4.865 sec)
# INFO:tensorflow:global_step/sec: 20.9243
# INFO:tensorflow:loss = 24.309372, step = 46387 (4.779 sec)
# INFO:tensorflow:global_step/sec: 20.5431
# INFO:tensorflow:loss = 22.549917, step = 46487 (4.868 sec)
# INFO:tensorflow:global_step/sec: 19.9476
# INFO:tensorflow:loss = 30.932806, step = 46587 (5.013 sec)
# INFO:tensorflow:global_step/sec: 20.0643
# INFO:tensorflow:loss = 18.110308, step = 46687 (4.984 sec)
# INFO:tensorflow:global_step/sec: 20.6603
# INFO:tensorflow:loss = 30.366056, step = 46787 (4.840 sec)
# INFO:tensorflow:global_step/sec: 20.1565
# INFO:tensorflow:loss = 24.206903, step = 46887 (4.961 sec)
# INFO:tensorflow:global_step/sec: 19.987
# INFO:tensorflow:loss = 28.192972, step = 46987 (5.004 sec)
# INFO:tensorflow:global_step/sec: 19.7385
# INFO:tensorflow:loss = 26.302526, step = 47087 (5.066 sec)
# INFO:tensorflow:global_step/sec: 19.9912
# INFO:tensorflow:loss = 34.86195, step = 47187 (5.002 sec)
# INFO:tensorflow:global_step/sec: 20.286
# INFO:tensorflow:loss = 30.587393, step = 47287 (4.930 sec)
# INFO:tensorflow:global_step/sec: 20.1027
# INFO:tensorflow:loss = 33.776024, step = 47387 (4.974 sec)
# INFO:tensorflow:global_step/sec: 19.972
# INFO:tensorflow:loss = 24.389046, step = 47487 (5.007 sec)
# INFO:tensorflow:global_step/sec: 19.9634
# INFO:tensorflow:loss = 26.767824, step = 47587 (5.009 sec)
# INFO:tensorflow:global_step/sec: 19.8789
# INFO:tensorflow:loss = 31.037933, step = 47687 (5.031 sec)
# INFO:tensorflow:global_step/sec: 19.8513
# INFO:tensorflow:loss = 30.218157, step = 47787 (5.037 sec)
# INFO:tensorflow:global_step/sec: 19.6249
# INFO:tensorflow:loss = 28.014912, step = 47887 (5.096 sec)
# INFO:tensorflow:global_step/sec: 20.1101
# INFO:tensorflow:loss = 37.261684, step = 47987 (4.972 sec)
# INFO:tensorflow:global_step/sec: 19.6633
# INFO:tensorflow:loss = 17.963085, step = 48087 (5.086 sec)
# INFO:tensorflow:global_step/sec: 19.9792
# INFO:tensorflow:loss = 26.369682, step = 48187 (5.005 sec)
# INFO:tensorflow:global_step/sec: 19.8759
# INFO:tensorflow:loss = 27.782227, step = 48287 (5.032 sec)
# INFO:tensorflow:global_step/sec: 19.9811
# INFO:tensorflow:loss = 24.357838, step = 48387 (5.005 sec)
# INFO:tensorflow:global_step/sec: 20.1031
# INFO:tensorflow:loss = 23.466913, step = 48487 (6.071 sec)
# INFO:tensorflow:global_step/sec: 16.411
# INFO:tensorflow:loss = 36.981567, step = 48587 (4.996 sec)
# INFO:tensorflow:global_step/sec: 20.0578
# INFO:tensorflow:loss = 20.453375, step = 48687 (4.985 sec)
# INFO:tensorflow:global_step/sec: 19.7027
# INFO:tensorflow:loss = 34.59761, step = 48787 (5.076 sec)
# INFO:tensorflow:global_step/sec: 19.5231
# INFO:tensorflow:loss = 21.180784, step = 48887 (5.122 sec)
# INFO:tensorflow:global_step/sec: 19.8828
# INFO:tensorflow:loss = 24.384266, step = 48987 (5.029 sec)
# INFO:tensorflow:global_step/sec: 19.4432
# INFO:tensorflow:loss = 19.88847, step = 49087 (5.143 sec)
# INFO:tensorflow:global_step/sec: 19.8373
# INFO:tensorflow:loss = 26.000957, step = 49187 (5.041 sec)
# INFO:tensorflow:global_step/sec: 20.1275
# INFO:tensorflow:loss = 25.852964, step = 49287 (4.968 sec)
# INFO:tensorflow:global_step/sec: 20.1453
# INFO:tensorflow:loss = 19.291447, step = 49387 (4.964 sec)
# INFO:tensorflow:global_step/sec: 19.4558
# INFO:tensorflow:loss = 23.98503, step = 49487 (5.141 sec)
# INFO:tensorflow:global_step/sec: 19.7704
# INFO:tensorflow:loss = 23.782877, step = 49587 (5.058 sec)
# INFO:tensorflow:global_step/sec: 19.2695
# INFO:tensorflow:loss = 19.592943, step = 49687 (5.189 sec)
# INFO:tensorflow:global_step/sec: 19.6669
# INFO:tensorflow:loss = 32.991714, step = 49787 (5.085 sec)
# INFO:tensorflow:global_step/sec: 19.2489
# INFO:tensorflow:loss = 21.183031, step = 49887 (5.195 sec)
# INFO:tensorflow:global_step/sec: 19.6081
# INFO:tensorflow:loss = 35.583973, step = 49987 (5.100 sec)
# INFO:tensorflow:global_step/sec: 20.2894
# INFO:tensorflow:loss = 21.436003, step = 50087 (4.929 sec)
# INFO:tensorflow:global_step/sec: 19.7786
# INFO:tensorflow:loss = 21.834694, step = 50187 (5.057 sec)
# INFO:tensorflow:global_step/sec: 19.8296
# INFO:tensorflow:loss = 24.319601, step = 50287 (5.042 sec)
# INFO:tensorflow:global_step/sec: 19.9857
# INFO:tensorflow:loss = 30.756693, step = 50387 (5.004 sec)
# INFO:tensorflow:global_step/sec: 19.5928
# INFO:tensorflow:loss = 25.58061, step = 50487 (5.104 sec)
# INFO:tensorflow:global_step/sec: 19.8743
# INFO:tensorflow:loss = 34.569347, step = 50587 (5.032 sec)
# INFO:tensorflow:global_step/sec: 20.0487
# INFO:tensorflow:loss = 28.835163, step = 50687 (4.988 sec)
# INFO:tensorflow:global_step/sec: 19.7655
# INFO:tensorflow:loss = 26.844427, step = 50787 (5.059 sec)
# INFO:tensorflow:global_step/sec: 19.8746
# INFO:tensorflow:loss = 27.704893, step = 50887 (6.296 sec)
# INFO:tensorflow:global_step/sec: 16.0822
# INFO:tensorflow:loss = 28.87165, step = 50987 (4.954 sec)
# INFO:tensorflow:global_step/sec: 20.1314
# INFO:tensorflow:loss = 22.914303, step = 51087 (4.967 sec)
# INFO:tensorflow:global_step/sec: 19.9752
# INFO:tensorflow:loss = 31.733496, step = 51187 (5.007 sec)
# INFO:tensorflow:global_step/sec: 20.163
# INFO:tensorflow:loss = 23.230843, step = 51287 (4.959 sec)
# INFO:tensorflow:global_step/sec: 20.1255
# INFO:tensorflow:loss = 18.049124, step = 51387 (4.968 sec)
# INFO:tensorflow:global_step/sec: 19.7639
# INFO:tensorflow:loss = 25.841547, step = 51487 (5.060 sec)
# INFO:tensorflow:global_step/sec: 20.3051
# INFO:tensorflow:loss = 26.730362, step = 51587 (4.925 sec)
# INFO:tensorflow:global_step/sec: 20.2063
# INFO:tensorflow:loss = 26.153997, step = 51687 (4.949 sec)
# INFO:tensorflow:global_step/sec: 20.0325
# INFO:tensorflow:loss = 25.36364, step = 51787 (4.992 sec)
# INFO:tensorflow:global_step/sec: 19.8935
# INFO:tensorflow:loss = 17.165678, step = 51887 (5.027 sec)
# INFO:tensorflow:global_step/sec: 19.9187
# INFO:tensorflow:loss = 26.89124, step = 51987 (5.020 sec)
# INFO:tensorflow:global_step/sec: 19.6705
# INFO:tensorflow:loss = 29.629288, step = 52087 (5.084 sec)
# INFO:tensorflow:global_step/sec: 19.9644
# INFO:tensorflow:loss = 34.456448, step = 52187 (5.009 sec)
# INFO:tensorflow:global_step/sec: 19.9652
# INFO:tensorflow:loss = 22.087118, step = 52287 (5.009 sec)
# INFO:tensorflow:global_step/sec: 19.5554
# INFO:tensorflow:loss = 21.32839, step = 52387 (5.114 sec)
# INFO:tensorflow:global_step/sec: 19.862
# INFO:tensorflow:loss = 19.127657, step = 52487 (5.034 sec)
# INFO:tensorflow:global_step/sec: 19.961
# INFO:tensorflow:loss = 23.535557, step = 52587 (5.010 sec)
# INFO:tensorflow:global_step/sec: 19.8038
# INFO:tensorflow:loss = 30.304129, step = 52687 (5.050 sec)
# INFO:tensorflow:global_step/sec: 19.8484
# INFO:tensorflow:loss = 32.075127, step = 52787 (5.038 sec)
# INFO:tensorflow:global_step/sec: 20.0283
# INFO:tensorflow:loss = 22.113203, step = 52887 (4.993 sec)
# INFO:tensorflow:global_step/sec: 20.1206
# INFO:tensorflow:loss = 25.806784, step = 52987 (4.970 sec)
# INFO:tensorflow:global_step/sec: 19.785
# INFO:tensorflow:loss = 27.521051, step = 53087 (5.054 sec)
# INFO:tensorflow:global_step/sec: 20.1645
# INFO:tensorflow:loss = 29.395962, step = 53187 (4.959 sec)
# INFO:tensorflow:global_step/sec: 20.5973
# INFO:tensorflow:loss = 23.746113, step = 53287 (6.138 sec)
# INFO:tensorflow:global_step/sec: 15.834
# INFO:tensorflow:loss = 28.279919, step = 53387 (5.033 sec)
# INFO:tensorflow:global_step/sec: 20.2871
# INFO:tensorflow:loss = 19.78295, step = 53487 (4.930 sec)
# INFO:tensorflow:global_step/sec: 19.7033
# INFO:tensorflow:loss = 25.59337, step = 53587 (5.075 sec)
# INFO:tensorflow:global_step/sec: 19.6749
# INFO:tensorflow:loss = 38.091305, step = 53687 (5.083 sec)
# INFO:tensorflow:global_step/sec: 19.7279
# INFO:tensorflow:loss = 19.322435, step = 53787 (5.069 sec)
# INFO:tensorflow:global_step/sec: 20.0953
# INFO:tensorflow:loss = 40.362823, step = 53887 (4.976 sec)
# INFO:tensorflow:global_step/sec: 20.1636
# INFO:tensorflow:loss = 30.632185, step = 53987 (4.960 sec)
# INFO:tensorflow:global_step/sec: 20.4977
# INFO:tensorflow:loss = 25.093079, step = 54087 (4.878 sec)
# INFO:tensorflow:global_step/sec: 20.1007
# INFO:tensorflow:loss = 27.959269, step = 54187 (4.974 sec)
# INFO:tensorflow:global_step/sec: 20.0993
# INFO:tensorflow:loss = 23.858568, step = 54287 (4.976 sec)
# INFO:tensorflow:global_step/sec: 20.0575
# INFO:tensorflow:loss = 34.225605, step = 54387 (4.985 sec)
# INFO:tensorflow:global_step/sec: 19.9225
# INFO:tensorflow:loss = 25.72072, step = 54487 (5.019 sec)
# INFO:tensorflow:global_step/sec: 20.0766
# INFO:tensorflow:loss = 33.642326, step = 54587 (4.981 sec)
# INFO:tensorflow:global_step/sec: 20.3777
# INFO:tensorflow:loss = 31.640854, step = 54687 (4.907 sec)
# INFO:tensorflow:global_step/sec: 20.218
# INFO:tensorflow:loss = 24.063406, step = 54787 (4.946 sec)
# INFO:tensorflow:global_step/sec: 19.7946
# INFO:tensorflow:loss = 28.796156, step = 54887 (5.052 sec)
# INFO:tensorflow:global_step/sec: 19.7714
# INFO:tensorflow:loss = 26.08105, step = 54987 (5.058 sec)
# INFO:tensorflow:global_step/sec: 20.2687
# INFO:tensorflow:loss = 23.130575, step = 55087 (4.934 sec)
# INFO:tensorflow:global_step/sec: 20.2041
# INFO:tensorflow:loss = 31.835892, step = 55187 (4.949 sec)
# INFO:tensorflow:global_step/sec: 19.976
# INFO:tensorflow:loss = 24.306547, step = 55287 (5.007 sec)
# INFO:tensorflow:global_step/sec: 19.9973
# INFO:tensorflow:loss = 31.623003, step = 55387 (5.000 sec)
# INFO:tensorflow:global_step/sec: 20.0985
# INFO:tensorflow:loss = 33.356026, step = 55487 (4.976 sec)
# INFO:tensorflow:Saving checkpoints for 55553 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:Loss for final step: 27.13979.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:05:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-55553
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:05:21
# INFO:tensorflow:Saving dict for global step 55553: accuracy = 0.7188, average_loss = 1.495445, global_step = 55553, loss = 149.5445
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-55553
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 55554 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:loss = 24.970411, step = 55554
# INFO:tensorflow:global_step/sec: 7.31433
# INFO:tensorflow:loss = 27.590769, step = 55654 (13.673 sec)
# INFO:tensorflow:global_step/sec: 20.1427
# INFO:tensorflow:loss = 26.395569, step = 55754 (6.153 sec)
# INFO:tensorflow:global_step/sec: 16.0662
# INFO:tensorflow:loss = 23.914473, step = 55854 (5.035 sec)
# INFO:tensorflow:global_step/sec: 20.1338
# INFO:tensorflow:loss = 29.18568, step = 55954 (4.967 sec)
# INFO:tensorflow:global_step/sec: 19.6183
# INFO:tensorflow:loss = 24.989902, step = 56054 (5.098 sec)
# INFO:tensorflow:global_step/sec: 19.8909
# INFO:tensorflow:loss = 19.281267, step = 56154 (5.027 sec)
# INFO:tensorflow:global_step/sec: 20.0519
# INFO:tensorflow:loss = 15.522488, step = 56254 (4.987 sec)
# INFO:tensorflow:global_step/sec: 20.667
# INFO:tensorflow:loss = 15.573518, step = 56354 (4.839 sec)
# INFO:tensorflow:global_step/sec: 19.9521
# INFO:tensorflow:loss = 19.374903, step = 56454 (5.012 sec)
# INFO:tensorflow:global_step/sec: 19.9718
# INFO:tensorflow:loss = 21.90842, step = 56554 (5.007 sec)
# INFO:tensorflow:global_step/sec: 19.9071
# INFO:tensorflow:loss = 17.810019, step = 56654 (5.023 sec)
# INFO:tensorflow:global_step/sec: 20.1435
# INFO:tensorflow:loss = 25.2534, step = 56754 (4.965 sec)
# INFO:tensorflow:global_step/sec: 19.9669
# INFO:tensorflow:loss = 36.1705, step = 56854 (5.008 sec)
# INFO:tensorflow:global_step/sec: 20.2662
# INFO:tensorflow:loss = 17.64695, step = 56954 (4.934 sec)
# INFO:tensorflow:global_step/sec: 20.2817
# INFO:tensorflow:loss = 32.45739, step = 57054 (4.930 sec)
# INFO:tensorflow:global_step/sec: 20.1595
# INFO:tensorflow:loss = 26.3968, step = 57154 (4.960 sec)
# INFO:tensorflow:global_step/sec: 19.8697
# INFO:tensorflow:loss = 21.580357, step = 57254 (5.032 sec)
# INFO:tensorflow:global_step/sec: 20.1014
# INFO:tensorflow:loss = 25.934175, step = 57354 (4.975 sec)
# INFO:tensorflow:global_step/sec: 20.3745
# INFO:tensorflow:loss = 27.73677, step = 57454 (4.908 sec)
# INFO:tensorflow:global_step/sec: 20.2884
# INFO:tensorflow:loss = 27.888088, step = 57554 (4.929 sec)
# INFO:tensorflow:global_step/sec: 19.6825
# INFO:tensorflow:loss = 30.425987, step = 57654 (5.081 sec)
# INFO:tensorflow:global_step/sec: 19.984
# INFO:tensorflow:loss = 26.650888, step = 57754 (5.004 sec)
# INFO:tensorflow:global_step/sec: 19.8608
# INFO:tensorflow:loss = 22.419315, step = 57854 (5.035 sec)
# INFO:tensorflow:global_step/sec: 19.8562
# INFO:tensorflow:loss = 32.51779, step = 57954 (5.036 sec)
# INFO:tensorflow:global_step/sec: 19.8426
# INFO:tensorflow:loss = 42.205265, step = 58054 (5.040 sec)
# INFO:tensorflow:global_step/sec: 19.715
# INFO:tensorflow:loss = 34.975918, step = 58154 (6.708 sec)
# INFO:tensorflow:global_step/sec: 14.7233
# INFO:tensorflow:loss = 21.401382, step = 58254 (5.156 sec)
# INFO:tensorflow:global_step/sec: 19.6274
# INFO:tensorflow:loss = 24.374105, step = 58354 (5.095 sec)
# INFO:tensorflow:global_step/sec: 19.813
# INFO:tensorflow:loss = 29.532589, step = 58454 (5.048 sec)
# INFO:tensorflow:global_step/sec: 20.0077
# INFO:tensorflow:loss = 21.527369, step = 58554 (4.998 sec)
# INFO:tensorflow:global_step/sec: 19.265
# INFO:tensorflow:loss = 29.974852, step = 58654 (5.190 sec)
# INFO:tensorflow:global_step/sec: 19.5222
# INFO:tensorflow:loss = 24.920753, step = 58754 (5.123 sec)
# INFO:tensorflow:global_step/sec: 20.0294
# INFO:tensorflow:loss = 32.241375, step = 58854 (4.993 sec)
# INFO:tensorflow:global_step/sec: 19.9495
# INFO:tensorflow:loss = 27.32621, step = 58954 (5.013 sec)
# INFO:tensorflow:global_step/sec: 19.7882
# INFO:tensorflow:loss = 22.394547, step = 59054 (5.054 sec)
# INFO:tensorflow:global_step/sec: 19.897
# INFO:tensorflow:loss = 22.836061, step = 59154 (5.026 sec)
# INFO:tensorflow:global_step/sec: 19.7362
# INFO:tensorflow:loss = 25.880684, step = 59254 (5.067 sec)
# INFO:tensorflow:global_step/sec: 19.485
# INFO:tensorflow:loss = 30.8058, step = 59354 (5.132 sec)
# INFO:tensorflow:global_step/sec: 19.595
# INFO:tensorflow:loss = 18.26867, step = 59454 (5.103 sec)
# INFO:tensorflow:global_step/sec: 19.7886
# INFO:tensorflow:loss = 23.33076, step = 59554 (5.054 sec)
# INFO:tensorflow:global_step/sec: 20.0714
# INFO:tensorflow:loss = 20.74928, step = 59654 (4.982 sec)
# INFO:tensorflow:global_step/sec: 19.9172
# INFO:tensorflow:loss = 29.959412, step = 59754 (5.021 sec)
# INFO:tensorflow:global_step/sec: 19.8592
# INFO:tensorflow:loss = 23.59334, step = 59854 (5.036 sec)
# INFO:tensorflow:global_step/sec: 19.6829
# INFO:tensorflow:loss = 24.010193, step = 59954 (5.081 sec)
# INFO:tensorflow:global_step/sec: 19.8751
# INFO:tensorflow:loss = 21.032846, step = 60054 (5.031 sec)
# INFO:tensorflow:global_step/sec: 19.7744
# INFO:tensorflow:loss = 22.785425, step = 60154 (5.057 sec)
# INFO:tensorflow:global_step/sec: 20.0571
# INFO:tensorflow:loss = 26.678493, step = 60254 (4.986 sec)
# INFO:tensorflow:global_step/sec: 19.9207
# INFO:tensorflow:loss = 30.113474, step = 60354 (5.020 sec)
# INFO:tensorflow:global_step/sec: 19.9759
# INFO:tensorflow:loss = 33.868603, step = 60454 (5.006 sec)
# INFO:tensorflow:global_step/sec: 20.1254
# INFO:tensorflow:loss = 22.241238, step = 60554 (6.145 sec)
# INFO:tensorflow:global_step/sec: 16.3618
# INFO:tensorflow:loss = 17.368244, step = 60654 (4.936 sec)
# INFO:tensorflow:global_step/sec: 19.9067
# INFO:tensorflow:loss = 32.287247, step = 60754 (5.024 sec)
# INFO:tensorflow:global_step/sec: 20.2164
# INFO:tensorflow:loss = 26.588158, step = 60854 (4.946 sec)
# INFO:tensorflow:global_step/sec: 19.4989
# INFO:tensorflow:loss = 25.91039, step = 60954 (5.128 sec)
# INFO:tensorflow:global_step/sec: 19.9049
# INFO:tensorflow:loss = 22.946465, step = 61054 (5.024 sec)
# INFO:tensorflow:global_step/sec: 19.8712
# INFO:tensorflow:loss = 23.176018, step = 61154 (5.032 sec)
# INFO:tensorflow:global_step/sec: 20.1011
# INFO:tensorflow:loss = 27.406525, step = 61254 (4.975 sec)
# INFO:tensorflow:global_step/sec: 19.9038
# INFO:tensorflow:loss = 25.19413, step = 61354 (5.024 sec)
# INFO:tensorflow:global_step/sec: 19.8007
# INFO:tensorflow:loss = 25.378933, step = 61454 (5.051 sec)
# INFO:tensorflow:global_step/sec: 20.1057
# INFO:tensorflow:loss = 29.032139, step = 61554 (4.973 sec)
# INFO:tensorflow:global_step/sec: 19.8088
# INFO:tensorflow:loss = 19.278128, step = 61654 (5.048 sec)
# INFO:tensorflow:global_step/sec: 19.8814
# INFO:tensorflow:loss = 27.089384, step = 61754 (5.030 sec)
# INFO:tensorflow:global_step/sec: 19.8581
# INFO:tensorflow:loss = 22.60594, step = 61854 (5.036 sec)
# INFO:tensorflow:global_step/sec: 20.3707
# INFO:tensorflow:loss = 22.219751, step = 61954 (4.909 sec)
# INFO:tensorflow:global_step/sec: 20.3983
# INFO:tensorflow:loss = 19.241064, step = 62054 (4.903 sec)
# INFO:tensorflow:global_step/sec: 19.984
# INFO:tensorflow:loss = 30.483822, step = 62154 (5.004 sec)
# INFO:tensorflow:global_step/sec: 20.0648
# INFO:tensorflow:loss = 23.87848, step = 62254 (4.983 sec)
# INFO:tensorflow:global_step/sec: 20.3097
# INFO:tensorflow:loss = 30.315481, step = 62354 (4.924 sec)
# INFO:tensorflow:global_step/sec: 19.961
# INFO:tensorflow:loss = 28.839434, step = 62454 (5.010 sec)
# INFO:tensorflow:global_step/sec: 20.3319
# INFO:tensorflow:loss = 22.911093, step = 62554 (4.919 sec)
# INFO:tensorflow:global_step/sec: 19.959
# INFO:tensorflow:loss = 31.71205, step = 62654 (5.010 sec)
# INFO:tensorflow:global_step/sec: 20.2519
# INFO:tensorflow:loss = 31.318573, step = 62754 (4.937 sec)
# INFO:tensorflow:global_step/sec: 20.0524
# INFO:tensorflow:loss = 23.108158, step = 62854 (4.987 sec)
# INFO:tensorflow:global_step/sec: 20.1245
# INFO:tensorflow:loss = 29.534473, step = 62954 (6.233 sec)
# INFO:tensorflow:global_step/sec: 15.9106
# INFO:tensorflow:loss = 25.195435, step = 63054 (5.022 sec)
# INFO:tensorflow:global_step/sec: 20.1857
# INFO:tensorflow:loss = 18.913527, step = 63154 (4.954 sec)
# INFO:tensorflow:global_step/sec: 20.1988
# INFO:tensorflow:loss = 29.998466, step = 63254 (4.951 sec)
# INFO:tensorflow:global_step/sec: 19.8464
# INFO:tensorflow:loss = 21.26114, step = 63354 (5.039 sec)
# INFO:tensorflow:global_step/sec: 19.8632
# INFO:tensorflow:loss = 24.814623, step = 63454 (5.034 sec)
# INFO:tensorflow:global_step/sec: 19.9493
# INFO:tensorflow:loss = 26.966368, step = 63554 (5.013 sec)
# INFO:tensorflow:global_step/sec: 19.5373
# INFO:tensorflow:loss = 20.227684, step = 63654 (5.119 sec)
# INFO:tensorflow:global_step/sec: 18.9219
# INFO:tensorflow:loss = 27.651024, step = 63754 (5.284 sec)
# INFO:tensorflow:global_step/sec: 17.6503
# INFO:tensorflow:loss = 27.782732, step = 63854 (5.666 sec)
# INFO:tensorflow:global_step/sec: 19.4581
# INFO:tensorflow:loss = 32.90168, step = 63954 (5.140 sec)
# INFO:tensorflow:global_step/sec: 19.2329
# INFO:tensorflow:loss = 29.721004, step = 64054 (5.199 sec)
# INFO:tensorflow:global_step/sec: 20.4469
# INFO:tensorflow:loss = 28.150122, step = 64154 (4.891 sec)
# INFO:tensorflow:global_step/sec: 20.2074
# INFO:tensorflow:loss = 27.205519, step = 64254 (4.949 sec)
# INFO:tensorflow:global_step/sec: 20.0317
# INFO:tensorflow:loss = 28.776506, step = 64354 (4.992 sec)
# INFO:tensorflow:global_step/sec: 20.1445
# INFO:tensorflow:loss = 27.229546, step = 64454 (4.964 sec)
# INFO:tensorflow:global_step/sec: 20.6362
# INFO:tensorflow:loss = 25.021553, step = 64554 (4.846 sec)
# INFO:tensorflow:global_step/sec: 21.0115
# INFO:tensorflow:loss = 21.81456, step = 64654 (4.759 sec)
# INFO:tensorflow:global_step/sec: 20.7709
# INFO:tensorflow:loss = 20.3631, step = 64754 (4.815 sec)
# INFO:tensorflow:global_step/sec: 20.5716
# INFO:tensorflow:loss = 28.027897, step = 64854 (4.861 sec)
# INFO:tensorflow:global_step/sec: 20.4932
# INFO:tensorflow:loss = 23.825335, step = 64954 (4.880 sec)
# INFO:tensorflow:global_step/sec: 20.3813
# INFO:tensorflow:loss = 19.943947, step = 65054 (4.906 sec)
# INFO:tensorflow:global_step/sec: 20.5385
# INFO:tensorflow:loss = 27.074467, step = 65154 (4.869 sec)
# INFO:tensorflow:global_step/sec: 20.3683
# INFO:tensorflow:loss = 23.661133, step = 65254 (4.909 sec)
# INFO:tensorflow:global_step/sec: 20.6462
# INFO:tensorflow:loss = 30.205566, step = 65354 (6.047 sec)
# INFO:tensorflow:global_step/sec: 16.8371
# INFO:tensorflow:loss = 26.092031, step = 65454 (4.736 sec)
# INFO:tensorflow:global_step/sec: 20.8239
# INFO:tensorflow:loss = 16.288193, step = 65554 (4.802 sec)
# INFO:tensorflow:global_step/sec: 20.5117
# INFO:tensorflow:loss = 29.405474, step = 65654 (4.875 sec)
# INFO:tensorflow:global_step/sec: 20.2963
# INFO:tensorflow:loss = 26.59875, step = 65754 (4.928 sec)
# INFO:tensorflow:global_step/sec: 19.269
# INFO:tensorflow:loss = 35.727768, step = 65854 (5.189 sec)
# INFO:tensorflow:global_step/sec: 19.1794
# INFO:tensorflow:loss = 24.22105, step = 65954 (5.214 sec)
# INFO:tensorflow:global_step/sec: 18.7121
# INFO:tensorflow:loss = 23.279636, step = 66054 (5.345 sec)
# INFO:tensorflow:global_step/sec: 18.9995
# INFO:tensorflow:loss = 24.936579, step = 66154 (5.264 sec)
# INFO:tensorflow:global_step/sec: 18.8755
# INFO:tensorflow:loss = 24.414877, step = 66254 (5.296 sec)
# INFO:tensorflow:Saving checkpoints for 66283 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:Loss for final step: 25.662817.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:16:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-66283
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:16:34
# INFO:tensorflow:Saving dict for global step 66283: accuracy = 0.7034, average_loss = 1.5417795, global_step = 66283, loss = 154.17795
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-66283
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 66284 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:loss = 27.996532, step = 66284
# INFO:tensorflow:global_step/sec: 7.46434
# INFO:tensorflow:loss = 26.642696, step = 66384 (13.398 sec)
# INFO:tensorflow:global_step/sec: 20.1804
# INFO:tensorflow:loss = 21.963408, step = 66484 (4.956 sec)
# INFO:tensorflow:global_step/sec: 20.0571
# INFO:tensorflow:loss = 34.174152, step = 66584 (4.985 sec)
# INFO:tensorflow:global_step/sec: 20.0284
# INFO:tensorflow:loss = 37.542976, step = 66684 (4.993 sec)
# INFO:tensorflow:global_step/sec: 20.1463
# INFO:tensorflow:loss = 18.515879, step = 66784 (4.964 sec)
# INFO:tensorflow:global_step/sec: 20.2598
# INFO:tensorflow:loss = 24.186148, step = 66884 (4.935 sec)
# INFO:tensorflow:global_step/sec: 20.1963
# INFO:tensorflow:loss = 25.00505, step = 66984 (4.952 sec)
# INFO:tensorflow:global_step/sec: 20.5898
# INFO:tensorflow:loss = 22.42007, step = 67084 (4.857 sec)
# INFO:tensorflow:global_step/sec: 20.1542
# INFO:tensorflow:loss = 26.873655, step = 67184 (4.961 sec)
# INFO:tensorflow:global_step/sec: 20.5013
# INFO:tensorflow:loss = 26.456488, step = 67284 (4.878 sec)
# INFO:tensorflow:global_step/sec: 20.3449
# INFO:tensorflow:loss = 25.768248, step = 67384 (4.916 sec)
# INFO:tensorflow:global_step/sec: 20.3206
# INFO:tensorflow:loss = 24.822107, step = 67484 (4.921 sec)
# INFO:tensorflow:global_step/sec: 19.7844
# INFO:tensorflow:loss = 33.63845, step = 67584 (5.054 sec)
# INFO:tensorflow:global_step/sec: 20.237
# INFO:tensorflow:loss = 20.696001, step = 67684 (4.941 sec)
# INFO:tensorflow:global_step/sec: 19.9026
# INFO:tensorflow:loss = 24.296274, step = 67784 (5.025 sec)
# INFO:tensorflow:global_step/sec: 20.0507
# INFO:tensorflow:loss = 34.830997, step = 67884 (4.987 sec)
# INFO:tensorflow:global_step/sec: 20.0499
# INFO:tensorflow:loss = 31.055527, step = 67984 (4.987 sec)
# INFO:tensorflow:global_step/sec: 19.9214
# INFO:tensorflow:loss = 22.92331, step = 68084 (6.267 sec)
# INFO:tensorflow:global_step/sec: 16.2124
# INFO:tensorflow:loss = 29.158644, step = 68184 (4.921 sec)
# INFO:tensorflow:global_step/sec: 19.9601
# INFO:tensorflow:loss = 26.510445, step = 68284 (5.010 sec)
# INFO:tensorflow:global_step/sec: 20.1921
# INFO:tensorflow:loss = 24.138641, step = 68384 (4.953 sec)
# INFO:tensorflow:global_step/sec: 20.0801
# INFO:tensorflow:loss = 25.583866, step = 68484 (4.980 sec)
# INFO:tensorflow:global_step/sec: 20.1636
# INFO:tensorflow:loss = 22.494091, step = 68584 (4.959 sec)
# INFO:tensorflow:global_step/sec: 20.1744
# INFO:tensorflow:loss = 25.26229, step = 68684 (4.957 sec)
# INFO:tensorflow:global_step/sec: 20.3238
# INFO:tensorflow:loss = 23.16338, step = 68784 (4.921 sec)
# INFO:tensorflow:global_step/sec: 19.6005
# INFO:tensorflow:loss = 25.802973, step = 68884 (5.102 sec)
# INFO:tensorflow:global_step/sec: 20.2932
# INFO:tensorflow:loss = 24.44731, step = 68984 (4.927 sec)
# INFO:tensorflow:global_step/sec: 20.4677
# INFO:tensorflow:loss = 23.39095, step = 69084 (4.886 sec)
# INFO:tensorflow:global_step/sec: 20.3372
# INFO:tensorflow:loss = 33.922565, step = 69184 (4.916 sec)
# INFO:tensorflow:global_step/sec: 20.2179
# INFO:tensorflow:loss = 22.113306, step = 69284 (4.946 sec)
# INFO:tensorflow:global_step/sec: 20.09
# INFO:tensorflow:loss = 31.77236, step = 69384 (4.977 sec)
# INFO:tensorflow:global_step/sec: 20.2093
# INFO:tensorflow:loss = 21.485846, step = 69484 (4.949 sec)
# INFO:tensorflow:global_step/sec: 20.0995
# INFO:tensorflow:loss = 20.269606, step = 69584 (4.974 sec)
# INFO:tensorflow:global_step/sec: 20.2971
# INFO:tensorflow:loss = 30.972246, step = 69684 (4.927 sec)
# INFO:tensorflow:global_step/sec: 20.4462
# INFO:tensorflow:loss = 23.216875, step = 69784 (4.891 sec)
# INFO:tensorflow:global_step/sec: 20.0338
# INFO:tensorflow:loss = 24.259592, step = 69884 (4.991 sec)
# INFO:tensorflow:global_step/sec: 20.0339
# INFO:tensorflow:loss = 27.950264, step = 69984 (4.992 sec)
# INFO:tensorflow:global_step/sec: 19.9408
# INFO:tensorflow:loss = 27.370327, step = 70084 (5.015 sec)
# INFO:tensorflow:global_step/sec: 19.7326
# INFO:tensorflow:loss = 29.105856, step = 70184 (5.067 sec)
# INFO:tensorflow:global_step/sec: 20.8218
# INFO:tensorflow:loss = 34.624153, step = 70284 (4.803 sec)
# INFO:tensorflow:global_step/sec: 19.6845
# INFO:tensorflow:loss = 31.138998, step = 70384 (5.080 sec)
# INFO:tensorflow:global_step/sec: 19.7322
# INFO:tensorflow:loss = 21.508728, step = 70484 (6.458 sec)
# INFO:tensorflow:global_step/sec: 15.6023
# INFO:tensorflow:loss = 25.55406, step = 70584 (5.020 sec)
# INFO:tensorflow:global_step/sec: 19.7808
# INFO:tensorflow:loss = 18.187868, step = 70684 (5.056 sec)
# INFO:tensorflow:global_step/sec: 19.9686
# INFO:tensorflow:loss = 26.729267, step = 70784 (5.008 sec)
# INFO:tensorflow:global_step/sec: 19.9194
# INFO:tensorflow:loss = 25.940905, step = 70884 (5.020 sec)
# INFO:tensorflow:global_step/sec: 19.899
# INFO:tensorflow:loss = 19.044811, step = 70984 (5.026 sec)
# INFO:tensorflow:global_step/sec: 20.1662
# INFO:tensorflow:loss = 23.971466, step = 71084 (4.959 sec)
# INFO:tensorflow:global_step/sec: 20.1289
# INFO:tensorflow:loss = 21.359713, step = 71184 (4.968 sec)
# INFO:tensorflow:global_step/sec: 19.867
# INFO:tensorflow:loss = 31.440056, step = 71284 (5.034 sec)
# INFO:tensorflow:global_step/sec: 19.8068
# INFO:tensorflow:loss = 20.00588, step = 71384 (5.048 sec)
# INFO:tensorflow:global_step/sec: 20.0479
# INFO:tensorflow:loss = 28.418648, step = 71484 (4.988 sec)
# INFO:tensorflow:global_step/sec: 20.8558
# INFO:tensorflow:loss = 22.277664, step = 71584 (4.795 sec)
# INFO:tensorflow:global_step/sec: 20.0251
# INFO:tensorflow:loss = 22.95177, step = 71684 (4.993 sec)
# INFO:tensorflow:global_step/sec: 20.1497
# INFO:tensorflow:loss = 18.973497, step = 71784 (4.963 sec)
# INFO:tensorflow:global_step/sec: 20.3203
# INFO:tensorflow:loss = 25.177416, step = 71884 (4.922 sec)
# INFO:tensorflow:global_step/sec: 20.1674
# INFO:tensorflow:loss = 22.355623, step = 71984 (4.958 sec)
# INFO:tensorflow:global_step/sec: 20.2716
# INFO:tensorflow:loss = 20.344103, step = 72084 (4.933 sec)
# INFO:tensorflow:global_step/sec: 19.8586
# INFO:tensorflow:loss = 35.49938, step = 72184 (5.036 sec)
# INFO:tensorflow:global_step/sec: 20.1534
# INFO:tensorflow:loss = 29.199884, step = 72284 (4.961 sec)
# INFO:tensorflow:global_step/sec: 20.0451
# INFO:tensorflow:loss = 27.188465, step = 72384 (4.989 sec)
# INFO:tensorflow:global_step/sec: 20.0025
# INFO:tensorflow:loss = 28.049747, step = 72484 (5.000 sec)
# INFO:tensorflow:global_step/sec: 20.2478
# INFO:tensorflow:loss = 23.203875, step = 72584 (4.938 sec)
# INFO:tensorflow:global_step/sec: 20.0019
# INFO:tensorflow:loss = 23.090204, step = 72684 (4.999 sec)
# INFO:tensorflow:global_step/sec: 19.8577
# INFO:tensorflow:loss = 32.562214, step = 72784 (5.036 sec)
# INFO:tensorflow:global_step/sec: 19.9658
# INFO:tensorflow:loss = 22.651743, step = 72884 (6.283 sec)
# INFO:tensorflow:global_step/sec: 15.9435
# INFO:tensorflow:loss = 26.82537, step = 72984 (4.998 sec)
# INFO:tensorflow:global_step/sec: 20.213
# INFO:tensorflow:loss = 33.0566, step = 73084 (4.947 sec)
# INFO:tensorflow:global_step/sec: 20.0743
# INFO:tensorflow:loss = 21.669909, step = 73184 (4.982 sec)
# INFO:tensorflow:global_step/sec: 19.9549
# INFO:tensorflow:loss = 31.63424, step = 73284 (5.011 sec)
# INFO:tensorflow:global_step/sec: 20.0747
# INFO:tensorflow:loss = 22.208181, step = 73384 (4.982 sec)
# INFO:tensorflow:global_step/sec: 20.2881
# INFO:tensorflow:loss = 25.376202, step = 73484 (4.929 sec)
# INFO:tensorflow:global_step/sec: 20.3386
# INFO:tensorflow:loss = 35.85001, step = 73584 (4.916 sec)
# INFO:tensorflow:global_step/sec: 20.0934
# INFO:tensorflow:loss = 36.08696, step = 73684 (4.977 sec)
# INFO:tensorflow:global_step/sec: 19.9959
# INFO:tensorflow:loss = 29.727703, step = 73784 (5.001 sec)
# INFO:tensorflow:global_step/sec: 20.2164
# INFO:tensorflow:loss = 35.1582, step = 73884 (4.946 sec)
# INFO:tensorflow:global_step/sec: 19.9411
# INFO:tensorflow:loss = 20.79812, step = 73984 (5.015 sec)
# INFO:tensorflow:global_step/sec: 20.181
# INFO:tensorflow:loss = 34.22184, step = 74084 (4.956 sec)
# INFO:tensorflow:global_step/sec: 20.3754
# INFO:tensorflow:loss = 33.43267, step = 74184 (4.907 sec)
# INFO:tensorflow:global_step/sec: 20.2565
# INFO:tensorflow:loss = 15.132198, step = 74284 (4.937 sec)
# INFO:tensorflow:global_step/sec: 20.0519
# INFO:tensorflow:loss = 27.690321, step = 74384 (4.987 sec)
# INFO:tensorflow:global_step/sec: 20.2703
# INFO:tensorflow:loss = 24.505623, step = 74484 (4.934 sec)
# INFO:tensorflow:global_step/sec: 20.4088
# INFO:tensorflow:loss = 28.83925, step = 74584 (4.899 sec)
# INFO:tensorflow:global_step/sec: 20.1655
# INFO:tensorflow:loss = 21.321947, step = 74684 (4.960 sec)
# INFO:tensorflow:global_step/sec: 20.1412
# INFO:tensorflow:loss = 30.398668, step = 74784 (4.965 sec)
# INFO:tensorflow:global_step/sec: 19.5617
# INFO:tensorflow:loss = 26.899487, step = 74884 (5.112 sec)
# INFO:tensorflow:global_step/sec: 19.5986
# INFO:tensorflow:loss = 36.67368, step = 74984 (5.102 sec)
# INFO:tensorflow:global_step/sec: 19.8122
# INFO:tensorflow:loss = 23.739798, step = 75084 (5.048 sec)
# INFO:tensorflow:global_step/sec: 19.7653
# INFO:tensorflow:loss = 24.24203, step = 75184 (5.059 sec)
# INFO:tensorflow:global_step/sec: 19.9482
# INFO:tensorflow:loss = 24.94725, step = 75284 (6.657 sec)
# INFO:tensorflow:global_step/sec: 14.8032
# INFO:tensorflow:loss = 24.0966, step = 75384 (5.111 sec)
# INFO:tensorflow:global_step/sec: 19.9701
# INFO:tensorflow:loss = 21.654036, step = 75484 (5.008 sec)
# INFO:tensorflow:global_step/sec: 19.9717
# INFO:tensorflow:loss = 27.938766, step = 75584 (5.007 sec)
# INFO:tensorflow:global_step/sec: 20.0149
# INFO:tensorflow:loss = 31.158848, step = 75684 (4.996 sec)
# INFO:tensorflow:global_step/sec: 20.2191
# INFO:tensorflow:loss = 19.012474, step = 75784 (4.946 sec)
# INFO:tensorflow:global_step/sec: 20.1852
# INFO:tensorflow:loss = 21.108276, step = 75884 (4.955 sec)
# INFO:tensorflow:global_step/sec: 19.5631
# INFO:tensorflow:loss = 20.794624, step = 75984 (5.111 sec)
# INFO:tensorflow:global_step/sec: 19.4543
# INFO:tensorflow:loss = 33.013535, step = 76084 (5.140 sec)
# INFO:tensorflow:global_step/sec: 20.385
# INFO:tensorflow:loss = 22.121887, step = 76184 (4.906 sec)
# INFO:tensorflow:global_step/sec: 19.6968
# INFO:tensorflow:loss = 27.402557, step = 76284 (5.077 sec)
# INFO:tensorflow:global_step/sec: 19.9095
# INFO:tensorflow:loss = 20.53081, step = 76384 (5.023 sec)
# INFO:tensorflow:global_step/sec: 20.2873
# INFO:tensorflow:loss = 30.485498, step = 76484 (4.929 sec)
# INFO:tensorflow:global_step/sec: 20.2098
# INFO:tensorflow:loss = 25.47972, step = 76584 (4.948 sec)
# INFO:tensorflow:global_step/sec: 20.0905
# INFO:tensorflow:loss = 25.268288, step = 76684 (4.978 sec)
# INFO:tensorflow:global_step/sec: 20.0648
# INFO:tensorflow:loss = 26.886066, step = 76784 (4.983 sec)
# INFO:tensorflow:global_step/sec: 19.6829
# INFO:tensorflow:loss = 13.89892, step = 76884 (5.081 sec)
# INFO:tensorflow:global_step/sec: 19.7498
# INFO:tensorflow:loss = 21.951706, step = 76984 (5.063 sec)
# INFO:tensorflow:global_step/sec: 19.7355
# INFO:tensorflow:loss = 32.691387, step = 77084 (5.066 sec)
# INFO:tensorflow:Saving checkpoints for 77089 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:Loss for final step: 24.581223.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:27:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-77089
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:27:40
# INFO:tensorflow:Saving dict for global step 77089: accuracy = 0.7031, average_loss = 1.5880232, global_step = 77089, loss = 158.80232
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-77089
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 77090 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:loss = 19.612617, step = 77090
# INFO:tensorflow:global_step/sec: 7.44607
# INFO:tensorflow:loss = 26.83375, step = 77190 (13.431 sec)
# INFO:tensorflow:global_step/sec: 20.176
# INFO:tensorflow:loss = 32.457047, step = 77290 (4.956 sec)
# INFO:tensorflow:global_step/sec: 19.9621
# INFO:tensorflow:loss = 29.369848, step = 77390 (5.009 sec)
# INFO:tensorflow:global_step/sec: 19.8862
# INFO:tensorflow:loss = 18.502419, step = 77490 (5.029 sec)
# INFO:tensorflow:global_step/sec: 20.1843
# INFO:tensorflow:loss = 27.443516, step = 77590 (4.954 sec)
# INFO:tensorflow:global_step/sec: 20.1166
# INFO:tensorflow:loss = 35.16481, step = 77690 (4.971 sec)
# INFO:tensorflow:global_step/sec: 19.7127
# INFO:tensorflow:loss = 30.203716, step = 77790 (5.073 sec)
# INFO:tensorflow:global_step/sec: 20.2296
# INFO:tensorflow:loss = 18.86076, step = 77890 (4.944 sec)
# INFO:tensorflow:global_step/sec: 19.8069
# INFO:tensorflow:loss = 18.222637, step = 77990 (5.049 sec)
# INFO:tensorflow:global_step/sec: 19.7903
# INFO:tensorflow:loss = 28.160177, step = 78090 (5.053 sec)
# INFO:tensorflow:global_step/sec: 20.4924
# INFO:tensorflow:loss = 30.978758, step = 78190 (4.880 sec)
# INFO:tensorflow:global_step/sec: 19.968
# INFO:tensorflow:loss = 22.274208, step = 78290 (5.008 sec)
# INFO:tensorflow:global_step/sec: 20.0232
# INFO:tensorflow:loss = 29.35586, step = 78390 (4.995 sec)
# INFO:tensorflow:global_step/sec: 20.6406
# INFO:tensorflow:loss = 32.444767, step = 78490 (4.844 sec)
# INFO:tensorflow:global_step/sec: 20.2951
# INFO:tensorflow:loss = 33.231968, step = 78590 (4.928 sec)
# INFO:tensorflow:global_step/sec: 20.121
# INFO:tensorflow:loss = 22.48204, step = 78690 (4.970 sec)
# INFO:tensorflow:global_step/sec: 19.945
# INFO:tensorflow:loss = 26.786781, step = 78790 (5.014 sec)
# INFO:tensorflow:global_step/sec: 19.7086
# INFO:tensorflow:loss = 28.41573, step = 78890 (6.654 sec)
# INFO:tensorflow:global_step/sec: 15.3265
# INFO:tensorflow:loss = 29.24511, step = 78990 (4.945 sec)
# INFO:tensorflow:global_step/sec: 20.0863
# INFO:tensorflow:loss = 24.128395, step = 79090 (4.978 sec)
# INFO:tensorflow:global_step/sec: 20.2358
# INFO:tensorflow:loss = 18.403135, step = 79190 (4.942 sec)
# INFO:tensorflow:global_step/sec: 19.9948
# INFO:tensorflow:loss = 26.57222, step = 79290 (5.002 sec)
# INFO:tensorflow:global_step/sec: 20.485
# INFO:tensorflow:loss = 28.081264, step = 79390 (4.881 sec)
# INFO:tensorflow:global_step/sec: 19.9911
# INFO:tensorflow:loss = 27.41719, step = 79490 (5.002 sec)
# INFO:tensorflow:global_step/sec: 19.9344
# INFO:tensorflow:loss = 31.009348, step = 79590 (5.017 sec)
# INFO:tensorflow:global_step/sec: 20.6508
# INFO:tensorflow:loss = 32.696926, step = 79690 (4.843 sec)
# INFO:tensorflow:global_step/sec: 20.0887
# INFO:tensorflow:loss = 28.914324, step = 79790 (4.977 sec)
# INFO:tensorflow:global_step/sec: 20.157
# INFO:tensorflow:loss = 27.27371, step = 79890 (4.961 sec)
# INFO:tensorflow:global_step/sec: 19.9935
# INFO:tensorflow:loss = 22.532568, step = 79990 (5.002 sec)
# INFO:tensorflow:global_step/sec: 20.1305
# INFO:tensorflow:loss = 21.749043, step = 80090 (4.967 sec)
# INFO:tensorflow:global_step/sec: 19.9552
# INFO:tensorflow:loss = 30.410427, step = 80190 (5.011 sec)
# INFO:tensorflow:global_step/sec: 20.0254
# INFO:tensorflow:loss = 34.448685, step = 80290 (4.994 sec)
# INFO:tensorflow:global_step/sec: 19.8559
# INFO:tensorflow:loss = 23.87996, step = 80390 (5.037 sec)
# INFO:tensorflow:global_step/sec: 19.694
# INFO:tensorflow:loss = 28.993765, step = 80490 (5.078 sec)
# INFO:tensorflow:global_step/sec: 19.5459
# INFO:tensorflow:loss = 25.678026, step = 80590 (5.116 sec)
# INFO:tensorflow:global_step/sec: 19.8375
# INFO:tensorflow:loss = 21.028427, step = 80690 (5.041 sec)
# INFO:tensorflow:global_step/sec: 20.2097
# INFO:tensorflow:loss = 27.613716, step = 80790 (4.949 sec)
# INFO:tensorflow:global_step/sec: 20.3777
# INFO:tensorflow:loss = 26.164581, step = 80890 (4.907 sec)
# INFO:tensorflow:global_step/sec: 20.0663
# INFO:tensorflow:loss = 25.996748, step = 80990 (4.984 sec)
# INFO:tensorflow:global_step/sec: 20.2102
# INFO:tensorflow:loss = 28.495953, step = 81090 (4.948 sec)
# INFO:tensorflow:global_step/sec: 20.1684
# INFO:tensorflow:loss = 23.327892, step = 81190 (4.958 sec)
# INFO:tensorflow:global_step/sec: 19.9525
# INFO:tensorflow:loss = 22.033907, step = 81290 (6.637 sec)
# INFO:tensorflow:global_step/sec: 15.2425
# INFO:tensorflow:loss = 20.424337, step = 81390 (4.936 sec)
# INFO:tensorflow:global_step/sec: 20.3753
# INFO:tensorflow:loss = 22.318245, step = 81490 (4.907 sec)
# INFO:tensorflow:global_step/sec: 20.1006
# INFO:tensorflow:loss = 19.822214, step = 81590 (4.975 sec)
# INFO:tensorflow:global_step/sec: 20.231
# INFO:tensorflow:loss = 32.30921, step = 81690 (4.943 sec)
# INFO:tensorflow:global_step/sec: 20.2329
# INFO:tensorflow:loss = 25.56547, step = 81790 (4.942 sec)
# INFO:tensorflow:global_step/sec: 19.9314
# INFO:tensorflow:loss = 29.200645, step = 81890 (5.017 sec)
# INFO:tensorflow:global_step/sec: 20.0122
# INFO:tensorflow:loss = 27.900776, step = 81990 (4.997 sec)
# INFO:tensorflow:global_step/sec: 19.7964
# INFO:tensorflow:loss = 18.876434, step = 82090 (5.052 sec)
# INFO:tensorflow:global_step/sec: 20.3022
# INFO:tensorflow:loss = 27.24732, step = 82190 (4.926 sec)
# INFO:tensorflow:global_step/sec: 20.0245
# INFO:tensorflow:loss = 23.74623, step = 82290 (4.994 sec)
# INFO:tensorflow:global_step/sec: 20.4197
# INFO:tensorflow:loss = 26.82533, step = 82390 (4.897 sec)
# INFO:tensorflow:global_step/sec: 19.8538
# INFO:tensorflow:loss = 22.12707, step = 82490 (5.037 sec)
# INFO:tensorflow:global_step/sec: 19.8134
# INFO:tensorflow:loss = 22.365292, step = 82590 (5.047 sec)
# INFO:tensorflow:global_step/sec: 19.6781
# INFO:tensorflow:loss = 35.128407, step = 82690 (5.082 sec)
# INFO:tensorflow:global_step/sec: 19.806
# INFO:tensorflow:loss = 30.128263, step = 82790 (5.049 sec)
# INFO:tensorflow:global_step/sec: 19.9108
# INFO:tensorflow:loss = 28.838556, step = 82890 (5.023 sec)
# INFO:tensorflow:global_step/sec: 19.9608
# INFO:tensorflow:loss = 26.195293, step = 82990 (5.010 sec)
# INFO:tensorflow:global_step/sec: 19.9899
# INFO:tensorflow:loss = 25.90422, step = 83090 (5.002 sec)
# INFO:tensorflow:global_step/sec: 20.0479
# INFO:tensorflow:loss = 31.566677, step = 83190 (4.988 sec)
# INFO:tensorflow:global_step/sec: 19.7545
# INFO:tensorflow:loss = 21.728287, step = 83290 (5.062 sec)
# INFO:tensorflow:global_step/sec: 20.185
# INFO:tensorflow:loss = 23.355917, step = 83390 (4.954 sec)
# INFO:tensorflow:global_step/sec: 19.8964
# INFO:tensorflow:loss = 29.887897, step = 83490 (5.026 sec)
# INFO:tensorflow:global_step/sec: 19.8429
# INFO:tensorflow:loss = 28.11436, step = 83590 (5.040 sec)
# INFO:tensorflow:global_step/sec: 20.0164
# INFO:tensorflow:loss = 34.14273, step = 83690 (6.498 sec)
# INFO:tensorflow:global_step/sec: 15.2251
# INFO:tensorflow:loss = 26.497831, step = 83790 (5.066 sec)
# INFO:tensorflow:global_step/sec: 19.9753
# INFO:tensorflow:loss = 21.603863, step = 83890 (5.007 sec)
# INFO:tensorflow:global_step/sec: 19.9163
# INFO:tensorflow:loss = 22.984163, step = 83990 (5.021 sec)
# INFO:tensorflow:global_step/sec: 20.2257
# INFO:tensorflow:loss = 25.894033, step = 84090 (4.944 sec)
# INFO:tensorflow:global_step/sec: 19.9112
# INFO:tensorflow:loss = 25.069765, step = 84190 (5.022 sec)
# INFO:tensorflow:global_step/sec: 20.1919
# INFO:tensorflow:loss = 33.835155, step = 84290 (4.953 sec)
# INFO:tensorflow:global_step/sec: 20.6011
# INFO:tensorflow:loss = 24.078129, step = 84390 (4.854 sec)
# INFO:tensorflow:global_step/sec: 19.7708
# INFO:tensorflow:loss = 32.45974, step = 84490 (5.059 sec)
# INFO:tensorflow:global_step/sec: 19.4369
# INFO:tensorflow:loss = 21.84338, step = 84590 (5.144 sec)
# INFO:tensorflow:global_step/sec: 19.9371
# INFO:tensorflow:loss = 21.682802, step = 84690 (5.016 sec)
# INFO:tensorflow:global_step/sec: 19.7229
# INFO:tensorflow:loss = 17.666742, step = 84790 (5.070 sec)
# INFO:tensorflow:global_step/sec: 19.9266
# INFO:tensorflow:loss = 27.848269, step = 84890 (5.018 sec)
# INFO:tensorflow:global_step/sec: 20.0734
# INFO:tensorflow:loss = 28.78173, step = 84990 (4.982 sec)
# INFO:tensorflow:global_step/sec: 19.5138
# INFO:tensorflow:loss = 31.107548, step = 85090 (5.125 sec)
# INFO:tensorflow:global_step/sec: 19.832
# INFO:tensorflow:loss = 22.21261, step = 85190 (5.042 sec)
# INFO:tensorflow:global_step/sec: 19.8922
# INFO:tensorflow:loss = 19.317833, step = 85290 (5.027 sec)
# INFO:tensorflow:global_step/sec: 19.7964
# INFO:tensorflow:loss = 29.96505, step = 85390 (5.052 sec)
# INFO:tensorflow:global_step/sec: 19.4976
# INFO:tensorflow:loss = 29.228724, step = 85490 (5.128 sec)
# INFO:tensorflow:global_step/sec: 19.8065
# INFO:tensorflow:loss = 27.647429, step = 85590 (5.049 sec)
# INFO:tensorflow:global_step/sec: 19.6622
# INFO:tensorflow:loss = 21.728588, step = 85690 (5.086 sec)
# INFO:tensorflow:global_step/sec: 19.4714
# INFO:tensorflow:loss = 21.887375, step = 85790 (5.136 sec)
# INFO:tensorflow:global_step/sec: 19.817
# INFO:tensorflow:loss = 24.93265, step = 85890 (5.046 sec)
# INFO:tensorflow:global_step/sec: 19.8954
# INFO:tensorflow:loss = 33.71682, step = 85990 (5.026 sec)
# INFO:tensorflow:global_step/sec: 20.0892
# INFO:tensorflow:loss = 33.57965, step = 86090 (6.323 sec)
# INFO:tensorflow:global_step/sec: 15.5924
# INFO:tensorflow:loss = 37.517746, step = 86190 (5.068 sec)
# INFO:tensorflow:global_step/sec: 20.4316
# INFO:tensorflow:loss = 23.712202, step = 86290 (4.895 sec)
# INFO:tensorflow:global_step/sec: 19.7533
# INFO:tensorflow:loss = 22.018953, step = 86390 (5.062 sec)
# INFO:tensorflow:global_step/sec: 20.1082
# INFO:tensorflow:loss = 25.4871, step = 86490 (4.973 sec)
# INFO:tensorflow:global_step/sec: 20.519
# ...
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:38:48
# INFO:tensorflow:Saving dict for global step 87810: accuracy = 0.7031, average_loss = 1.6286674, global_step = 87810, loss = 162.86674
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-87810
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 87811 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:loss = 22.097878, step = 87811
# INFO:tensorflow:global_step/sec: 7.19534
# INFO:tensorflow:loss = 21.421812, step = 87911 (13.899 sec)
# INFO:tensorflow:global_step/sec: 19.8839
# INFO:tensorflow:loss = 18.762274, step = 88011 (5.029 sec)
# INFO:tensorflow:global_step/sec: 20.1442
# INFO:tensorflow:loss = 30.490276, step = 88111 (4.964 sec)
# INFO:tensorflow:global_step/sec: 19.8199
# INFO:tensorflow:loss = 19.592644, step = 88211 (5.045 sec)
# INFO:tensorflow:global_step/sec: 19.9033
# INFO:tensorflow:loss = 27.324934, step = 88311 (5.024 sec)
# INFO:tensorflow:global_step/sec: 20.2352
# INFO:tensorflow:loss = 18.001406, step = 88411 (4.942 sec)
# INFO:tensorflow:global_step/sec: 20.2257
# INFO:tensorflow:loss = 22.12621, step = 88511 (4.944 sec)
# INFO:tensorflow:global_step/sec: 20.6476
# INFO:tensorflow:loss = 21.769669, step = 88611 (4.843 sec)
# INFO:tensorflow:global_step/sec: 19.7495
# INFO:tensorflow:loss = 28.95395, step = 88711 (5.064 sec)
# INFO:tensorflow:global_step/sec: 19.9196
# INFO:tensorflow:loss = 21.208746, step = 88811 (5.020 sec)
# INFO:tensorflow:global_step/sec: 19.6918
# INFO:tensorflow:loss = 24.836317, step = 88911 (5.078 sec)
# INFO:tensorflow:global_step/sec: 19.7612
# INFO:tensorflow:loss = 27.872244, step = 89011 (5.061 sec)
# INFO:tensorflow:global_step/sec: 19.8404
# INFO:tensorflow:loss = 29.271418, step = 89111 (5.040 sec)
# INFO:tensorflow:global_step/sec: 19.7404
# INFO:tensorflow:loss = 22.62995, step = 89211 (5.066 sec)
# INFO:tensorflow:global_step/sec: 19.9797
# INFO:tensorflow:loss = 26.348818, step = 89311 (5.005 sec)
# INFO:tensorflow:global_step/sec: 20.4644
# INFO:tensorflow:loss = 31.628214, step = 89411 (4.886 sec)
# INFO:tensorflow:global_step/sec: 20.0184
# INFO:tensorflow:loss = 34.656727, step = 89511 (4.995 sec)
# INFO:tensorflow:global_step/sec: 19.8014
# INFO:tensorflow:loss = 24.94939, step = 89611 (6.637 sec)
# INFO:tensorflow:global_step/sec: 15.2121
# INFO:tensorflow:loss = 25.552227, step = 89711 (4.987 sec)
# INFO:tensorflow:global_step/sec: 20.3561
# INFO:tensorflow:loss = 22.130873, step = 89811 (4.912 sec)
# INFO:tensorflow:global_step/sec: 20.3933
# INFO:tensorflow:loss = 21.896196, step = 89911 (4.903 sec)
# INFO:tensorflow:global_step/sec: 20.1399
# INFO:tensorflow:loss = 25.523577, step = 90011 (4.966 sec)
# INFO:tensorflow:global_step/sec: 20.2414
# INFO:tensorflow:loss = 21.35325, step = 90111 (4.940 sec)
# INFO:tensorflow:global_step/sec: 20.4622
# INFO:tensorflow:loss = 23.8392, step = 90211 (4.888 sec)
# INFO:tensorflow:global_step/sec: 20.8288
# INFO:tensorflow:loss = 22.749544, step = 90311 (4.801 sec)
# INFO:tensorflow:global_step/sec: 20.2298
# INFO:tensorflow:loss = 21.803423, step = 90411 (4.943 sec)
# INFO:tensorflow:global_step/sec: 20.3077
# INFO:tensorflow:loss = 30.037027, step = 90511 (4.924 sec)
# INFO:tensorflow:global_step/sec: 20.1461
# INFO:tensorflow:loss = 25.245897, step = 90611 (4.964 sec)
# INFO:tensorflow:global_step/sec: 20.01
# INFO:tensorflow:loss = 22.559694, step = 90711 (4.998 sec)
# INFO:tensorflow:global_step/sec: 20.4998
# INFO:tensorflow:loss = 25.356146, step = 90811 (4.878 sec)
# INFO:tensorflow:global_step/sec: 20.1846
# INFO:tensorflow:loss = 22.41113, step = 90911 (4.954 sec)
# INFO:tensorflow:global_step/sec: 20.1155
# INFO:tensorflow:loss = 24.621452, step = 91011 (4.971 sec)
# INFO:tensorflow:global_step/sec: 20.0424
# INFO:tensorflow:loss = 28.013844, step = 91111 (4.990 sec)
# INFO:tensorflow:global_step/sec: 20.1559
# INFO:tensorflow:loss = 29.052254, step = 91211 (4.961 sec)
# INFO:tensorflow:global_step/sec: 20.1787
# INFO:tensorflow:loss = 22.323292, step = 91311 (4.956 sec)
# INFO:tensorflow:global_step/sec: 20.0286
# INFO:tensorflow:loss = 15.249532, step = 91411 (4.993 sec)
# INFO:tensorflow:global_step/sec: 20.08
# INFO:tensorflow:loss = 20.22561, step = 91511 (4.980 sec)
# INFO:tensorflow:global_step/sec: 20.2167
# INFO:tensorflow:loss = 29.424065, step = 91611 (4.947 sec)
# INFO:tensorflow:global_step/sec: 20.0704
# INFO:tensorflow:loss = 33.80108, step = 91711 (4.983 sec)
# INFO:tensorflow:global_step/sec: 19.9237
# INFO:tensorflow:loss = 30.282162, step = 91811 (5.019 sec)
# INFO:tensorflow:global_step/sec: 20.1553
# INFO:tensorflow:loss = 26.6972, step = 91911 (4.962 sec)
# INFO:tensorflow:global_step/sec: 20.136
# INFO:tensorflow:loss = 26.807775, step = 92011 (6.400 sec)
# INFO:tensorflow:global_step/sec: 15.5556
# INFO:tensorflow:loss = 33.985794, step = 92111 (4.995 sec)
# INFO:tensorflow:global_step/sec: 20.3384
# INFO:tensorflow:loss = 28.26309, step = 92211 (4.916 sec)
# INFO:tensorflow:global_step/sec: 20.0999
# INFO:tensorflow:loss = 27.916794, step = 92311 (4.976 sec)
# INFO:tensorflow:global_step/sec: 20.2965
# INFO:tensorflow:loss = 29.758818, step = 92411 (4.926 sec)
# INFO:tensorflow:global_step/sec: 20.5499
# INFO:tensorflow:loss = 28.737343, step = 92511 (4.867 sec)
# INFO:tensorflow:global_step/sec: 20.2439
# INFO:tensorflow:loss = 22.836945, step = 92611 (4.940 sec)
# INFO:tensorflow:global_step/sec: 20.1541
# INFO:tensorflow:loss = 24.015049, step = 92711 (4.962 sec)
# INFO:tensorflow:global_step/sec: 19.8791
# INFO:tensorflow:loss = 24.791561, step = 92811 (5.030 sec)
# INFO:tensorflow:global_step/sec: 20.0672
# INFO:tensorflow:loss = 22.466194, step = 92911 (4.983 sec)
# INFO:tensorflow:global_step/sec: 20.3466
# INFO:tensorflow:loss = 29.616041, step = 93011 (4.915 sec)
# INFO:tensorflow:global_step/sec: 21.0684
# INFO:tensorflow:loss = 22.198221, step = 93111 (4.747 sec)
# INFO:tensorflow:global_step/sec: 20.2923
# INFO:tensorflow:loss = 21.773972, step = 93211 (4.928 sec)
# INFO:tensorflow:global_step/sec: 19.9573
# INFO:tensorflow:loss = 17.33472, step = 93311 (5.011 sec)
# INFO:tensorflow:global_step/sec: 19.4464
# INFO:tensorflow:loss = 25.98743, step = 93411 (5.143 sec)
# INFO:tensorflow:global_step/sec: 18.1274
# INFO:tensorflow:loss = 28.558472, step = 93511 (5.517 sec)
# INFO:tensorflow:global_step/sec: 17.3425
# INFO:tensorflow:loss = 24.869326, step = 93611 (5.766 sec)
# INFO:tensorflow:global_step/sec: 19.9476
# INFO:tensorflow:loss = 26.983917, step = 93711 (5.013 sec)
# INFO:tensorflow:global_step/sec: 20.8359
# INFO:tensorflow:loss = 30.339804, step = 93811 (4.800 sec)
# INFO:tensorflow:global_step/sec: 20.8683
# INFO:tensorflow:loss = 21.93174, step = 93911 (4.791 sec)
# INFO:tensorflow:global_step/sec: 20.2132
# INFO:tensorflow:loss = 33.90526, step = 94011 (4.947 sec)
# INFO:tensorflow:global_step/sec: 20.0022
# INFO:tensorflow:loss = 24.140957, step = 94111 (4.999 sec)
# INFO:tensorflow:global_step/sec: 20.1844
# INFO:tensorflow:loss = 21.792355, step = 94211 (4.954 sec)
# INFO:tensorflow:global_step/sec: 19.9888
# INFO:tensorflow:loss = 25.71623, step = 94311 (5.003 sec)
# INFO:tensorflow:global_step/sec: 19.9405
# INFO:tensorflow:loss = 22.200987, step = 94411 (6.789 sec)
# INFO:tensorflow:global_step/sec: 14.7538
# INFO:tensorflow:loss = 30.049227, step = 94511 (5.004 sec)
# INFO:tensorflow:global_step/sec: 20.3856
# INFO:tensorflow:loss = 16.907185, step = 94611 (4.905 sec)
# INFO:tensorflow:global_step/sec: 20.3942
# INFO:tensorflow:loss = 20.395046, step = 94711 (4.903 sec)
# INFO:tensorflow:global_step/sec: 20.0802
# INFO:tensorflow:loss = 24.302214, step = 94811 (4.980 sec)
# INFO:tensorflow:global_step/sec: 20.0565
# INFO:tensorflow:loss = 24.438704, step = 94911 (4.986 sec)
# INFO:tensorflow:global_step/sec: 20.2129
# INFO:tensorflow:loss = 27.646374, step = 95011 (4.947 sec)
# INFO:tensorflow:global_step/sec: 20.1579
# INFO:tensorflow:loss = 16.429848, step = 95111 (4.961 sec)
# INFO:tensorflow:global_step/sec: 20.3382
# INFO:tensorflow:loss = 22.700542, step = 95211 (4.917 sec)
# INFO:tensorflow:global_step/sec: 20.3186
# INFO:tensorflow:loss = 28.143822, step = 95311 (4.921 sec)
# INFO:tensorflow:global_step/sec: 20.0887
# INFO:tensorflow:loss = 25.989758, step = 95411 (4.978 sec)
# INFO:tensorflow:global_step/sec: 20.1907
# INFO:tensorflow:loss = 25.271893, step = 95511 (4.953 sec)
# INFO:tensorflow:global_step/sec: 20.1795
# INFO:tensorflow:loss = 22.99326, step = 95611 (4.955 sec)
# INFO:tensorflow:global_step/sec: 20.4088
# INFO:tensorflow:loss = 26.899364, step = 95711 (4.900 sec)
# INFO:tensorflow:global_step/sec: 19.9322
# INFO:tensorflow:loss = 24.86902, step = 95811 (5.017 sec)
# INFO:tensorflow:global_step/sec: 20.3108
# INFO:tensorflow:loss = 25.74051, step = 95911 (4.924 sec)
# INFO:tensorflow:global_step/sec: 19.9151
# INFO:tensorflow:loss = 26.76372, step = 96011 (5.021 sec)
# INFO:tensorflow:global_step/sec: 19.7507
# INFO:tensorflow:loss = 21.157917, step = 96111 (5.063 sec)
# INFO:tensorflow:global_step/sec: 19.9662
# INFO:tensorflow:loss = 17.332329, step = 96211 (5.009 sec)
# INFO:tensorflow:global_step/sec: 20.2161
# INFO:tensorflow:loss = 24.005482, step = 96311 (4.946 sec)
# INFO:tensorflow:global_step/sec: 20.3287
# INFO:tensorflow:loss = 29.581533, step = 96411 (4.919 sec)
# INFO:tensorflow:global_step/sec: 19.8905
# INFO:tensorflow:loss = 23.10817, step = 96511 (5.028 sec)
# INFO:tensorflow:global_step/sec: 19.7161
# INFO:tensorflow:loss = 17.83506, step = 96611 (5.072 sec)
# INFO:tensorflow:global_step/sec: 19.9849
# INFO:tensorflow:loss = 23.216702, step = 96711 (5.004 sec)
# INFO:tensorflow:global_step/sec: 19.9144
# INFO:tensorflow:loss = 34.397087, step = 96811 (6.339 sec)
# INFO:tensorflow:global_step/sec: 15.9875
# INFO:tensorflow:loss = 38.64218, step = 96911 (4.938 sec)
# INFO:tensorflow:global_step/sec: 20.4581
# INFO:tensorflow:loss = 31.385382, step = 97011 (4.888 sec)
# INFO:tensorflow:global_step/sec: 19.7483
# INFO:tensorflow:loss = 24.161646, step = 97111 (5.064 sec)
# INFO:tensorflow:global_step/sec: 20.0036
# INFO:tensorflow:loss = 25.970947, step = 97211 (4.999 sec)
# INFO:tensorflow:global_step/sec: 19.9916
# INFO:tensorflow:loss = 27.01245, step = 97311 (5.002 sec)
# INFO:tensorflow:global_step/sec: 19.2484
# INFO:tensorflow:loss = 23.853277, step = 97411 (5.195 sec)
# INFO:tensorflow:global_step/sec: 19.9489
# INFO:tensorflow:loss = 23.836151, step = 97511 (5.013 sec)
# INFO:tensorflow:global_step/sec: 18.9833
# INFO:tensorflow:loss = 25.157972, step = 97611 (5.267 sec)
# INFO:tensorflow:global_step/sec: 19.8841
# INFO:tensorflow:loss = 21.946806, step = 97711 (5.029 sec)
# INFO:tensorflow:global_step/sec: 20.0224
# INFO:tensorflow:loss = 25.905762, step = 97811 (4.994 sec)
# INFO:tensorflow:global_step/sec: 19.6796
# INFO:tensorflow:loss = 23.162952, step = 97911 (5.081 sec)
# INFO:tensorflow:global_step/sec: 19.4616
# INFO:tensorflow:loss = 25.265158, step = 98011 (5.138 sec)
# INFO:tensorflow:global_step/sec: 19.9053
# INFO:tensorflow:loss = 32.328735, step = 98111 (5.024 sec)
# INFO:tensorflow:global_step/sec: 19.5712
# INFO:tensorflow:loss = 23.632427, step = 98211 (5.110 sec)
# INFO:tensorflow:global_step/sec: 20.0504
# INFO:tensorflow:loss = 21.698128, step = 98311 (4.988 sec)
# INFO:tensorflow:global_step/sec: 19.4738
# INFO:tensorflow:loss = 20.355219, step = 98411 (5.135 sec)
# INFO:tensorflow:global_step/sec: 19.7043
# INFO:tensorflow:loss = 25.37307, step = 98511 (5.075 sec)
# INFO:tensorflow:Saving checkpoints for 98566 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:Loss for final step: 26.51717.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:49:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-98566
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:49:55
# INFO:tensorflow:Saving dict for global step 98566: accuracy = 0.6718, average_loss = 1.6687467, global_step = 98566, loss = 166.87466
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-98566
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 98567 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:loss = 26.94676, step = 98567
# INFO:tensorflow:global_step/sec: 7.47662
# INFO:tensorflow:loss = 35.14801, step = 98667 (13.376 sec)
# INFO:tensorflow:global_step/sec: 20.2223
# INFO:tensorflow:loss = 34.506695, step = 98767 (4.946 sec)
# INFO:tensorflow:global_step/sec: 20.0473
# INFO:tensorflow:loss = 19.765718, step = 98867 (4.989 sec)
# INFO:tensorflow:global_step/sec: 20.1102
# INFO:tensorflow:loss = 23.65825, step = 98967 (4.972 sec)
# INFO:tensorflow:global_step/sec: 20.0129
# INFO:tensorflow:loss = 32.040565, step = 99067 (4.996 sec)
# INFO:tensorflow:global_step/sec: 19.9934
# INFO:tensorflow:loss = 35.335743, step = 99167 (5.002 sec)
# INFO:tensorflow:global_step/sec: 19.2329
# INFO:tensorflow:loss = 20.171074, step = 99267 (5.199 sec)
# INFO:tensorflow:global_step/sec: 19.8982
# INFO:tensorflow:loss = 31.57442, step = 99367 (5.025 sec)
# INFO:tensorflow:global_step/sec: 19.5493
# INFO:tensorflow:loss = 36.125652, step = 99467 (5.116 sec)
# INFO:tensorflow:global_step/sec: 19.2654
# INFO:tensorflow:loss = 32.60023, step = 99567 (5.190 sec)
# INFO:tensorflow:global_step/sec: 19.4491
# INFO:tensorflow:loss = 22.55226, step = 99667 (5.141 sec)
# INFO:tensorflow:global_step/sec: 19.611
# INFO:tensorflow:loss = 25.43688, step = 99767 (5.100 sec)
# INFO:tensorflow:global_step/sec: 19.5408
# INFO:tensorflow:loss = 23.428886, step = 99867 (5.118 sec)
# INFO:tensorflow:global_step/sec: 19.4883
# INFO:tensorflow:loss = 25.765766, step = 99967 (5.131 sec)
# INFO:tensorflow:Saving checkpoints for 100000 into gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt.
# INFO:tensorflow:Loss for final step: 27.959217.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:53:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-100000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:54:12
# INFO:tensorflow:Saving dict for global step 100000: accuracy = 0.6719, average_loss = 1.6734045, global_step = 100000, loss = 167.34045

# %%
df[COLUMNS]
# Out:
#      Gender Eye_color     Hair_color Alignment Agility Accelerated_Healing  \
# 0      Male      gold           Gold       bad   FALSE               FALSE
# 1    Female      blue          Blond       bad   FALSE               FALSE
# 2    Female    indigo          Black   neutral   FALSE               FALSE
# 3      Male         -          Black       bad    TRUE                TRUE
# 4      Male         -              -       bad    TRUE               FALSE
# 5      Male         -              -       bad   FALSE               FALSE
# 6      Male      blue          Black      good   FALSE               FALSE
# 7      Male     green          Blond       bad    TRUE               FALSE
# 8      Male      blue          Blond   neutral    TRUE                TRUE
# 9      Male         -              -       bad    TRUE                TRUE
# 10     Male      blue  Brown / White      good   FALSE                TRUE
# 11     Male     green        No Hair       bad    TRUE               FALSE
# 12   Female     white          Blond      good   FALSE                TRUE
# 13     Male     brown          Brown       bad   FALSE               FALSE
# 14     Male      grey        No Hair       bad    TRUE                TRUE
# 15     Male      blue          Blond      good   FALSE               FALSE
# 16     Male         -              -       bad   FALSE               FALSE
# 17     Male      bown          Black      good    TRUE                TRUE
# 18   Female     brown          Black      good   FALSE               FALSE
# 19     Male      blue          Blond      good    TRUE                TRUE
# 20     Male     brown          Black      good    TRUE               FALSE
# 21     Male     brown         Auburn      good   FALSE               FALSE
# 22     Male     brown          Brown      good   FALSE               FALSE
# 23   Female     green          Black      good   FALSE               FALSE
# 24   Female     brown            Red       bad   FALSE               FALSE
# 25     Male     white        No Hair      good   FALSE               FALSE
# 26     Male      blue          Blond      good    TRUE                TRUE
# 27   Female      blue            Red      good   FALSE               FALSE
# 28     Male      blue        No Hair       bad   FALSE               FALSE
# 29     Male     brown          Black      good   FALSE               FALSE
# ..      ...       ...            ...       ...     ...                 ...
# 559       -     white         Yellow      good   FALSE               FALSE
# 560    Male      blue          Blond      good   FALSE               FALSE
# 561    Male     brown              -      good   FALSE               FALSE
# 562  Female         -              -      good   FALSE                TRUE
# 563  Female      blue          Blond      good   FALSE               FALSE
# 564    Male     black          Black   neutral   FALSE                TRUE
# 565  Female      blue          Blond      good    TRUE                TRUE
# 566    Male     brown          Brown       bad    TRUE               FALSE
# 567    Male       red          Black       bad   FALSE                TRUE
# 568    Male      blue         Auburn       bad   FALSE                TRUE
# 569  Female      blue          Blond      good   FALSE               FALSE
# 570  Female      blue         Purple       bad   FALSE               FALSE
# 571    Male     brown          Brown      good   FALSE               FALSE
# 572       -       red          Brown      good    TRUE                TRUE
# 573    Male     green          Green       bad   FALSE               FALSE
# 574    Male      blue            Red      good    TRUE               FALSE
# 575    Male      blue           Blue      good    TRUE                TRUE
# 576    Male    yellow          Black       bad   FALSE                TRUE
# 577  Female     black          Black      good   FALSE               FALSE
# 578    Male     white          Black       bad   FALSE                TRUE
# 579    Male      blue          Black      good   FALSE               FALSE
# 580  Female     brown          Black      good   FALSE               FALSE
# 581    Male     brown          Black       bad    TRUE               FALSE
# 582    Male         -              -      good   FALSE               FALSE
# 583    Male         -              -       bad    TRUE                TRUE
# 584       -     brown  Brown / Black      good   FALSE               FALSE
# 585  Female      blue          Blond      good    TRUE               FALSE
# 586    Male      blue         Silver      good   FALSE               FALSE
# 587  Female     green          Brown      good   FALSE               FALSE
# 588  Female     brown          Black      good   FALSE               FALSE
#
#     Lantern_Power_Ring Dimensional_Awareness Cold_Resistance Durability  \
# 0                FALSE                 FALSE           FALSE       TRUE
# 1                FALSE                 FALSE            TRUE       TRUE
# 2                FALSE                 FALSE           FALSE      FALSE
# 3                FALSE                 FALSE           FALSE      FALSE
# 4                FALSE                 FALSE           FALSE      FALSE
# 5                FALSE                 FALSE           FALSE       TRUE
# 6                FALSE                 FALSE           FALSE      FALSE
# 7                FALSE                 FALSE           FALSE       TRUE
# 8                FALSE                 FALSE           FALSE      FALSE
# 9                FALSE                 FALSE           FALSE       TRUE
# 10               FALSE                 FALSE           FALSE      FALSE
# 11               FALSE                 FALSE           FALSE       TRUE
# 12               FALSE                 FALSE           FALSE      FALSE
# 13               FALSE                 FALSE           FALSE       TRUE
# 14               FALSE                 FALSE            TRUE       TRUE
# 15               FALSE                 FALSE           FALSE      FALSE
# 16               FALSE                 FALSE           FALSE      FALSE
# 17                TRUE                 FALSE           FALSE      FALSE
# 18               FALSE                 FALSE           FALSE      FALSE
# 19               FALSE                 FALSE           FALSE       TRUE
# 20               FALSE                 FALSE           FALSE      FALSE
# 21               FALSE                 FALSE           FALSE      FALSE
# 22               FALSE                 FALSE           FALSE      FALSE
# 23               FALSE                 FALSE           FALSE      FALSE
# 24               FALSE                 FALSE           FALSE       TRUE
# 25               FALSE                 FALSE           FALSE       TRUE
# 26               FALSE                 FALSE            TRUE       TRUE
# 27               FALSE                 FALSE           FALSE       TRUE
# 28               FALSE                 FALSE           FALSE      FALSE
# 29               FALSE                 FALSE           FALSE       TRUE
# ..                 ...                   ...             ...        ...
# 559              FALSE                 FALSE           FALSE       TRUE
# 560              FALSE                 FALSE           FALSE       TRUE
# 561              FALSE                 FALSE           FALSE      FALSE
# 562              FALSE                 FALSE           FALSE       TRUE
# 563              FALSE                 FALSE           FALSE      FALSE
# 564              FALSE                  TRUE           FALSE       TRUE
# 565              FALSE                 FALSE           FALSE       TRUE
# 566              FALSE                 FALSE           FALSE       TRUE
# 567              FALSE                 FALSE           FALSE       TRUE
# 568              FALSE                 FALSE           FALSE       TRUE
# 569              FALSE                 FALSE           FALSE      FALSE
# 570              FALSE                 FALSE            TRUE       TRUE
# 571              FALSE                 FALSE           FALSE      FALSE
# 572              FALSE                 FALSE           FALSE       TRUE
# 573              FALSE                 FALSE           FALSE       TRUE
# 574              FALSE                 FALSE           FALSE      FALSE
# 575              FALSE                 FALSE           FALSE      FALSE
# 576              FALSE                 FALSE           FALSE      FALSE
# 577              FALSE                 FALSE           FALSE      FALSE
# 578              FALSE                  TRUE           FALSE       TRUE
# 579              FALSE                 FALSE           FALSE      FALSE
# 580              FALSE                 FALSE           FALSE      FALSE
# 581              FALSE                 FALSE           FALSE      FALSE
# 582              FALSE                 FALSE            TRUE      FALSE
# 583              FALSE                 FALSE           FALSE      FALSE
# 584              FALSE                 FALSE           FALSE      FALSE
# 585              FALSE                 FALSE           FALSE      FALSE
# 586              FALSE                 FALSE           FALSE       TRUE
# 587              FALSE                 FALSE           FALSE      FALSE
# 588              FALSE                 FALSE           FALSE      FALSE
#
#        ...     Web_Creation Reality_Warping Odin_Force Symbiote_Costume  \
# 0      ...            FALSE           FALSE      FALSE            FALSE
# 1      ...            FALSE           FALSE      FALSE            FALSE
# 2      ...            FALSE           FALSE      FALSE            FALSE
# 3      ...            FALSE           FALSE      FALSE            FALSE
# 4      ...            FALSE           FALSE      FALSE            FALSE
# 5      ...            FALSE           FALSE      FALSE            FALSE
# 6      ...            FALSE           FALSE      FALSE            FALSE
# 7      ...            FALSE           FALSE      FALSE            FALSE
# 8      ...            FALSE           FALSE      FALSE            FALSE
# 9      ...            FALSE           FALSE      FALSE            FALSE
# 10     ...            FALSE           FALSE      FALSE            FALSE
# 11     ...            FALSE           FALSE      FALSE            FALSE
# 12     ...            FALSE           FALSE      FALSE            FALSE
# 13     ...            FALSE           FALSE      FALSE            FALSE
# 14     ...            FALSE           FALSE      FALSE            FALSE
# 15     ...            FALSE           FALSE      FALSE            FALSE
# 16     ...            FALSE           FALSE      FALSE            FALSE
# 17     ...            FALSE           FALSE      FALSE            FALSE
# 18     ...            FALSE           FALSE      FALSE            FALSE
# 19     ...            FALSE           FALSE       TRUE            FALSE
# 20     ...            FALSE           FALSE      FALSE            FALSE
# 21     ...            FALSE           FALSE      FALSE            FALSE
# 22     ...            FALSE           FALSE      FALSE            FALSE
# 23     ...            FALSE           FALSE      FALSE            FALSE
# 24     ...            FALSE           FALSE      FALSE            FALSE
# 25     ...            FALSE           FALSE      FALSE            FALSE
# 26     ...            FALSE           FALSE      FALSE            FALSE
# 27     ...            FALSE           FALSE      FALSE            FALSE
# 28     ...            FALSE           FALSE      FALSE            FALSE
# 29     ...            FALSE           FALSE      FALSE            FALSE
# ..     ...              ...             ...        ...              ...
# 559    ...            FALSE           FALSE      FALSE            FALSE
# 560    ...            FALSE           FALSE      FALSE            FALSE
# 561    ...            FALSE           FALSE      FALSE            FALSE
# 562    ...            FALSE           FALSE      FALSE            FALSE
# 563    ...            FALSE           FALSE      FALSE            FALSE
# 564    ...            FALSE           FALSE      FALSE            FALSE
# 565    ...            FALSE           FALSE      FALSE            FALSE
# 566    ...            FALSE           FALSE      FALSE            FALSE
# 567    ...            FALSE           FALSE      FALSE            FALSE
# 568    ...            FALSE           FALSE      FALSE            FALSE
# 569    ...            FALSE           FALSE      FALSE            FALSE
# 570    ...            FALSE           FALSE      FALSE            FALSE
# 571    ...            FALSE           FALSE      FALSE            FALSE
# 572    ...             TRUE           FALSE      FALSE            FALSE
# 573    ...            FALSE           FALSE      FALSE            FALSE
# 574    ...            FALSE           FALSE      FALSE            FALSE
# 575    ...            FALSE           FALSE      FALSE            FALSE
# 576    ...            FALSE           FALSE      FALSE            FALSE
# 577    ...            FALSE           FALSE      FALSE            FALSE
# 578    ...            FALSE           FALSE      FALSE            FALSE
# 579    ...            FALSE           FALSE      FALSE            FALSE
# 580    ...            FALSE           FALSE      FALSE            FALSE
# 581    ...            FALSE           FALSE      FALSE            FALSE
# 582    ...            FALSE           FALSE      FALSE            FALSE
# 583    ...            FALSE           FALSE      FALSE            FALSE
# 584    ...            FALSE           FALSE      FALSE            FALSE
# 585    ...            FALSE           FALSE      FALSE            FALSE
# 586    ...            FALSE           FALSE      FALSE            FALSE
# 587    ...            FALSE           FALSE      FALSE            FALSE
# 588    ...            FALSE           FALSE      FALSE            FALSE
#
#     Speed_Force Phoenix_Force Molecular_Dissipation Vision_Cryo Omnipresent  \
# 0         FALSE         FALSE                 FALSE       FALSE       FALSE
# 1         FALSE         FALSE                 FALSE       FALSE       FALSE
# 2         FALSE         FALSE                 FALSE       FALSE       FALSE
# 3         FALSE         FALSE                 FALSE       FALSE       FALSE
# 4         FALSE         FALSE                 FALSE       FALSE       FALSE
# 5         FALSE         FALSE                 FALSE       FALSE       FALSE
# 6         FALSE         FALSE                 FALSE       FALSE       FALSE
# 7         FALSE         FALSE                 FALSE       FALSE       FALSE
# 8         FALSE         FALSE                 FALSE       FALSE       FALSE
# 9         FALSE         FALSE                 FALSE       FALSE       FALSE
# 10        FALSE         FALSE                 FALSE       FALSE       FALSE
# 11        FALSE         FALSE                 FALSE       FALSE       FALSE
# 12        FALSE         FALSE                 FALSE       FALSE       FALSE
# 13        FALSE         FALSE                 FALSE       FALSE       FALSE
# 14        FALSE         FALSE                 FALSE       FALSE       FALSE
# 15        FALSE         FALSE                 FALSE       FALSE       FALSE
# 16        FALSE         FALSE                 FALSE       FALSE       FALSE
# 17        FALSE         FALSE                 FALSE       FALSE       FALSE
# 18        FALSE         FALSE                 FALSE       FALSE       FALSE
# 19        FALSE         FALSE                 FALSE       FALSE       FALSE
# 20        FALSE         FALSE                 FALSE       FALSE       FALSE
# 21        FALSE         FALSE                 FALSE       FALSE       FALSE
# 22        FALSE         FALSE                 FALSE       FALSE       FALSE
# 23        FALSE         FALSE                 FALSE       FALSE       FALSE
# 24        FALSE         FALSE                 FALSE       FALSE       FALSE
# 25        FALSE         FALSE                 FALSE       FALSE       FALSE
# 26        FALSE         FALSE                 FALSE       FALSE       FALSE
# 27        FALSE         FALSE                 FALSE       FALSE       FALSE
# 28        FALSE         FALSE                 FALSE       FALSE       FALSE
# 29        FALSE         FALSE                 FALSE       FALSE       FALSE
# ..          ...           ...                   ...         ...         ...
# 559       FALSE         FALSE                 FALSE       FALSE       FALSE
# 560       FALSE         FALSE                 FALSE       FALSE       FALSE
# 561       FALSE         FALSE                 FALSE       FALSE       FALSE
# 562       FALSE         FALSE                 FALSE       FALSE       FALSE
# 563       FALSE         FALSE                 FALSE       FALSE       FALSE
# 564       FALSE         FALSE                 FALSE       FALSE       FALSE
# 565       FALSE         FALSE                 FALSE       FALSE       FALSE
# 566       FALSE         FALSE                 FALSE       FALSE       FALSE
# 567       FALSE         FALSE                 FALSE       FALSE       FALSE
# 568       FALSE         FALSE                 FALSE       FALSE       FALSE
# 569       FALSE         FALSE                 FALSE       FALSE       FALSE
# 570       FALSE         FALSE                 FALSE       FALSE       FALSE
# 571       FALSE         FALSE                 FALSE       FALSE       FALSE
# 572       FALSE         FALSE                 FALSE       FALSE       FALSE
# 573       FALSE         FALSE                 FALSE       FALSE       FALSE
# 574       FALSE         FALSE                 FALSE       FALSE       FALSE
# 575       FALSE         FALSE                 FALSE       FALSE       FALSE
# 576       FALSE         FALSE                 FALSE       FALSE       FALSE
# 577       FALSE         FALSE                 FALSE       FALSE       FALSE
# 578       FALSE         FALSE                 FALSE       FALSE       FALSE
# 579       FALSE         FALSE                 FALSE       FALSE       FALSE
# 580       FALSE         FALSE                 FALSE       FALSE       FALSE
# 581       FALSE         FALSE                 FALSE       FALSE       FALSE
# 582       FALSE         FALSE                 FALSE       FALSE       FALSE
# 583       FALSE         FALSE                 FALSE       FALSE       FALSE
# 584       FALSE         FALSE                 FALSE       FALSE       FALSE
# 585       FALSE         FALSE                 FALSE       FALSE       FALSE
# 586       FALSE         FALSE                 FALSE       FALSE       FALSE
# 587       FALSE         FALSE                 FALSE       FALSE       FALSE
# 588       FALSE         FALSE                 FALSE       FALSE       FALSE
#
#     Omniscient
# 0        FALSE
# 1        FALSE
# 2        FALSE
# 3        FALSE
# 4        FALSE
# 5        FALSE
# 6        FALSE
# 7        FALSE
# 8        FALSE
# 9        FALSE
# 10       FALSE
# 11       FALSE
# 12       FALSE
# 13       FALSE
# 14       FALSE
# 15       FALSE
# 16       FALSE
# 17       FALSE
# 18       FALSE
# 19       FALSE
# 20       FALSE
# 21       FALSE
# 22       FALSE
# 23       FALSE
# 24       FALSE
# 25       FALSE
# 26       FALSE
# 27       FALSE
# 28       FALSE
# 29       FALSE
# ..         ...
# 559      FALSE
# 560      FALSE
# 561      FALSE
# 562      FALSE
# 563      FALSE
# 564      FALSE
# 565      FALSE
# 566      FALSE
# 567      FALSE
# 568      FALSE
# 569      FALSE
# 570      FALSE
# 571      FALSE
# 572      FALSE
# 573      FALSE
# 574      FALSE
# 575      FALSE
# 576      FALSE
# 577      FALSE
# 578      FALSE
# 579      FALSE
# 580      FALSE
# 581      FALSE
# 582      FALSE
# 583      FALSE
# 584      FALSE
# 585      FALSE
# 586      FALSE
# 587      FALSE
# 588      FALSE
#
# [589 rows x 171 columns]

# %%
print()
tf.estimator.train_and_evaluate(
    est,
    tf.estimator.TrainSpec(input_fn=create_trainset, max_steps=TRAIN_STEPS),
    tf.estimator.EvalSpec(input_fn=create_evalset, steps=df_eval.shape[0])
)
# Out:
# ()
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Skipping training since max_steps has already saved.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:54:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-100000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [6/64]
# INFO:tensorflow:Evaluation [12/64]
# INFO:tensorflow:Evaluation [18/64]
# INFO:tensorflow:Evaluation [24/64]
# INFO:tensorflow:Evaluation [30/64]
# INFO:tensorflow:Evaluation [36/64]
# INFO:tensorflow:Evaluation [42/64]
# INFO:tensorflow:Evaluation [48/64]
# INFO:tensorflow:Evaluation [54/64]
# INFO:tensorflow:Evaluation [60/64]
# INFO:tensorflow:Evaluation [64/64]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:54:38
# INFO:tensorflow:Saving dict for global step 100000: accuracy = 0.671875, average_loss = 1.6733872, global_step = 100000, loss = 167.33871

# %%
tf.estimator.train_and_evaluate(
    est,
    tf.estimator.TrainSpec(input_fn=create_trainset, max_steps=TRAIN_STEPS),
    tf.estimator.EvalSpec(input_fn=create_trainset)
)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Skipping training since max_steps has already saved.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-11:54:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-100000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [80/100]
# INFO:tensorflow:Evaluation [90/100]
# INFO:tensorflow:Evaluation [100/100]
# INFO:tensorflow:Finished evaluation at 2018-06-07-11:55:07
# INFO:tensorflow:Saving dict for global step 100000: accuracy = 0.8963, average_loss = 0.2549337, global_step = 100000, loss = 25.493372

# %%
COLUMNS
# Out:
# ['Gender',
#  'Eye_color',
#  'Hair_color',
#  'Alignment',
#  'Agility',
#  'Accelerated_Healing',
#  'Lantern_Power_Ring',
#  'Dimensional_Awareness',
#  'Cold_Resistance',
#  'Durability',
#  'Stealth',
#  'Energy_Absorption',
#  'Flight',
#  'Danger_Sense',
#  'Underwater_breathing',
#  'Marksmanship',
#  'Weapons_Master',
#  'Power_Augmentation',
#  'Animal_Attributes',
#  'Longevity',
#  'Intelligence',
#  'Super_Strength',
#  'Cryokinesis',
#  'Telepathy',
#  'Energy_Armor',
#  'Energy_Blasts',
#  'Duplication',
#  'Size_Changing',
#  'Density_Control',
#  'Stamina',
#  'Astral_Travel',
#  'Audio_Control',
#  'Dexterity',
#  'Omnitrix',
#  'Super_Speed',
#  'Possession',
#  'Animal_Oriented_Powers',
#  'Weapon-based_Powers',
#  'Electrokinesis',
#  'Darkforce_Manipulation',
#  'Death_Touch',
#  'Teleportation',
#  'Enhanced_Senses',
#  'Telekinesis',
#  'Energy_Beams',
#  'Magic',
#  'Hyperkinesis',
#  'Jump',
#  'Clairvoyance',
#  'Dimensional_Travel',
#  'Power_Sense',
#  'Shapeshifting',
#  'Peak_Human_Condition',
#  'Immortality',
#  'Camouflage',
#  'Element_Control',
#  'Phasing',
#  'Astral_Projection',
#  'Electrical_Transport',
#  'Fire_Control',
#  'Projection',
#  'Summoning',
#  'Enhanced_Memory',
#  'Reflexes',
#  'Invulnerability',
#  'Energy_Constructs',
#  'Force_Fields',
#  'Self-Sustenance',
#  'Anti-Gravity',
#  'Empathy',
#  'Power_Nullifier',
#  'Radiation_Control',
#  'Psionic_Powers',
#  'Elasticity',
#  'Substance_Secretion',
#  'Elemental_Transmogrification',
#  'Technopath/Cyberpath',
#  'Photographic_Reflexes',
#  'Seismic_Power',
#  'Animation',
#  'Precognition',
#  'Mind_Control',
#  'Fire_Resistance',
#  'Power_Absorption',
#  'Enhanced_Hearing',
#  'Nova_Force',
#  'Insanity',
#  'Hypnokinesis',
#  'Animal_Control',
#  'Natural_Armor',
#  'Intangibility',
#  'Enhanced_Sight',
#  'Molecular_Manipulation',
#  'Heat_Generation',
#  'Adaptation',
#  'Gliding',
#  'Power_Suit',
#  'Mind_Blast',
#  'Probability_Manipulation',
#  'Gravity_Control',
#  'Regeneration',
#  'Light_Control',
#  'Echolocation',
#  'Levitation',
#  'Toxin_and_Disease_Control',
#  'Banish',
#  'Energy_Manipulation',
#  'Heat_Resistance',
#  'Natural_Weapons',
#  'Time_Travel',
#  'Enhanced_Smell',
#  'Illusions',
#  'Thirstokinesis',
#  'Hair_Manipulation',
#  'Illumination',
#  'Omnipotent',
#  'Cloaking',
#  'Changing_Armor',
#  'Power_Cosmic',
#  'Biokinesis',
#  'Water_Control',
#  'Radiation_Immunity',
#  'Vision_Telescopic',
#  'Toxin_and_Disease_Resistance',
#  'Spatial_Awareness',
#  'Energy_Resistance',
#  'Telepathy_Resistance',
#  'Molecular_Combustion',
#  'Omnilingualism',
#  'Portal_Creation',
#  'Magnetism',
#  'Mind_Control_Resistance',
#  'Plant_Control',
#  'Sonar',
#  'Sonic_Scream',
#  'Time_Manipulation',
#  'Enhanced_Touch',
#  'Magic_Resistance',
#  'Invisibility',
#  'Sub-Mariner',
#  'Radiation_Absorption',
#  'Intuitive_aptitude',
#  'Vision_Microscopic',
#  'Melting',
#  'Wind_Control',
#  'Super_Breath',
#  'Wallcrawling',
#  'Vision_Night',
#  'Vision_Infrared',
#  'Grim_Reaping',
#  'Matter_Absorption',
#  'The_Force',
#  'Resurrection',
#  'Terrakinesis',
#  'Vision_Heat',
#  'Vitakinesis',
#  'Radar_Sense',
#  'Qwardian_Power_Ring',
#  'Weather_Control',
#  'Vision_X-Ray',
#  'Vision_Thermal',
#  'Web_Creation',
#  'Reality_Warping',
#  'Odin_Force',
#  'Symbiote_Costume',
#  'Speed_Force',
#  'Phoenix_Force',
#  'Molecular_Dissipation',
#  'Vision_Cryo',
#  'Omnipresent',
#  'Omniscient']

# %% [markdown]
# ### export the model

# %%
# attempt 2
feature_spec = tf.feature_column.make_parse_example_spec(feature_columns)
export_input_fn = tf.estimator.export.build_parsing_serving_input_receiver_fn(feature_spec)
#export_input_fn = tf.contrib.learn.build_parsing_serving_input_fn(feature_spec)
servable_model_path=est.export_savedmodel(os.path.join(MODEL_DIR,"model"),export_input_fn)
servable_model_path
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: ['serving_default', 'classification']
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict']
# INFO:tensorflow:Restoring parameters from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model.ckpt-100000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model/temp-1528372522/saved_model.pb
# 'gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model/1528372522'

# %%
with open_file(os.path.join(MODEL_DIR,"data","latest_model.txt"), "w") as f:
    f.write(servable_model_path)

# %%
raise
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-18-9c9a2cba73bf> in <module>()
# ----> 1 raise
#
# TypeError: exceptions must be old-style classes or derived from BaseException, not NoneType

# %% [markdown]
# # INFERENCE: TENSORFLOW MODEL SERVER

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import json
import os
import pandas as pd

import numpy as np
import tensorflow as tf
from tensorflow.python.lib.io.file_io import FileIO as open_file

# %%
from tensorflow_model_server.tensorflow_model_server import TensorflowModelServer
from tensorflow_model_server.inout.requests import build_estimator_request, EstimatorRequest

# %%
MODEL_PATH=servable_model_path
with open_file(os.path.join(MODEL_DIR,"data","dataset_fields.json"), "r") as f:
    inputs_definition=json.load(f)
    
COLUMNS=inputs_definition["fields"]["columns"]
FIELD_TYPES=inputs_definition["fields"]["types"]
FIELD_CATEGORIES=inputs_definition["fields"]["categories"]
LABELS=inputs_definition["label"]["categories"]

# %%
with open_file(os.path.join(MODEL_DIR,"data","actual_evalset.csv"), "r") as f:
    df = pd.read_csv(f)
for c in df.columns:
    if df[c].dtypes.name == 'bool':
        df[c]=df[c].map({True: 'TRUE', False: 'FALSE'})

# %%
def extract_outcomes(predictions):
    for p in predictions:
        if(not p["net"]["success"]):
            print(p)
            raise
    
    return [p["net"]["result"]["classes"][np.argmax(
        p["net"]["result"]["scores"]
    )] for p in predictions]

# %%
BATCH_SIZE=15
heroes=list(df["index"].values)
requests=[]
expected_results=[]
results=[]
for i,h in enumerate(heroes):
    feats=list(df[df["index"]==h].drop([LABEL_FIELD], axis=1).values[0][1:])
    requests.append({
        "COLUMNS":COLUMNS,
        "FIELD_TYPES":FIELD_TYPES,
        "features":feats
    })
    expected_results.append(df[df["index"]==h][LABEL_FIELD].values[0])
chunks = [requests[x:x+BATCH_SIZE] for x in xrange(0, len(requests), BATCH_SIZE)]

with TensorflowModelServer(
    {"net":MODEL_PATH}, 
    request_builder=build_estimator_request
) as tms:
    for i,c in enumerate(chunks):
        print((i,len(chunks)))
        results.extend(extract_outcomes(tms.predict(c)))
# Out:
# downloading models...
# downloading net from gs://ml-research-injenia/estimators/trainings/linear-classifier/test08/model/1528372522 to ./tensorflow_model_server_staging/net
# model net downloaded to /notebooks/MIRCO/Estimators/tensorflow_model_server_staging/net
# launching:
# tensorflow_model_server --port=9000 --model_config_file=./tensorflow_model_server_staging/config.yaml
# 2018-06-07 12:46:55.319729: I tensorflow_serving/model_servers/server_core.cc:444] Adding/updating models.
#
# 2018-06-07 12:46:55.319778: I tensorflow_serving/model_servers/server_core.cc:499]  (Re-)adding model: net
#
# 2018-06-07 12:46:55.420209: I tensorflow_serving/core/basic_manager.cc:716] Successfully reserved resources to load servable {name: net version: 1}
#
# 2018-06-07 12:46:55.420250: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: net version: 1}
#
# 2018-06-07 12:46:55.420259: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: net version: 1}
#
# 2018-06-07 12:46:55.420275: I external/org_tensorflow/tensorflow/contrib/session_bundle/bundle_shim.cc:360] Attempting to load native SavedModelBundle in bundle-shim from: /notebooks/MIRCO/Estimators/tensorflow_model_server_staging/net/1
#
# 2018-06-07 12:46:55.420288: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:242] Loading SavedModel with tags: { serve }; from: /notebooks/MIRCO/Estimators/tensorflow_model_server_staging/net/1
#
# 2018-06-07 12:46:55.507241: I external/org_tensorflow/tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
#
# 2018-06-07 12:46:55.706405: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:161] Restoring SavedModel bundle.
#
# 2018-06-07 12:46:55.822668: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:196] Running LegacyInitOp on SavedModel bundle.
#
# 2018-06-07 12:46:56.043787: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:291] SavedModel load for tags { serve }; Status: success. Took 623485 microseconds.
#
# 2018-06-07 12:46:56.053433: I tensorflow_serving/core/loader_harness.cc:86] Successfully loaded servable version {name: net version: 1}
#
# 2018-06-07 12:46:56.056635: I tensorflow_serving/model_servers/main.cc:316] Running ModelServer at 0.0.0.0:9000 ...
#
# (0, 5)
# tearing down tensorflow_model_server
# tear down complete
# cleaning up ./tensorflow_model_server_staging
# clean up complete
# <type 'exceptions.KeyboardInterrupt'>
#   File "<ipython-input-28-896caab8137a>", line 22, in <module>
#     results.extend(extract_outcomes(tms.predict(c)))
#   File "tensorflow_model_server/tensorflow_model_server.py", line 271, in predict
#     response_formatter=self.response_formatter)
#   File "tensorflow_model_server/parallel_prediction.py", line 137, in parallel_batch_predictions
#     results = [q.get() for p in processes]
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 117, in get
#     res = self._recv()

# %%
correct=0
total=0
for i,result in enumerate(results):
    if result==expected_results[i]:
        correct+=1
    total+=1
print("Accuracy:")
print(float(correct)/float(total))
# Out:
# Accuracy:
# ZeroDivisionErrorTraceback (most recent call last)
# <ipython-input-29-a66f9bb8d0a3> in <module>()
#       6     total+=1
#       7 print("Accuracy:")
# ----> 8 print(float(correct)/float(total))
#
# ZeroDivisionError: float division by zero

# %%
BATCH_SIZE=15
heroes=list(df["index"].values)
requests=[]
expected_results=[]
results=[]
for i,h in enumerate(heroes):
    feats=list(df[df["index"]==h].drop([LABEL_FIELD], axis=1).values[0][1:])
    requests.append(feats)
    expected_results.append(df[df["index"]==h][LABEL_FIELD].values[0])
    
chunks = [requests[x:x+BATCH_SIZE] for x in xrange(0, len(requests), BATCH_SIZE)]

with TensorflowModelServer(
    {"net":MODEL_PATH}, 
    request_builder=EstimatorRequest(COLUMNS,FIELD_TYPES)
) as tms:
    for c in chunks:
        results.extend(extract_outcomes(tms.predict(c)))

# %%
correct=0
total=0
for i,result in enumerate(results):
    if result==expected_results[i]:
        correct+=1
    total+=1
print("Accuracy:")
print(float(correct)/float(total))

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
# %matplotlib inline

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def confusion_matrix(y_test, y_pred):
    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_test, y_pred)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
# THIS IS TO STOP THE "RESTART AND RUN ALL" COMMAND
raise

# %% [markdown]
# # EXPERIMENTS

# %%
tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)

# %%
est.get_variable_names()

# %%
weights_name="linear/linear_model/Accelerated_Healing/weights"
est.get_variable_value(weights_name)

# %%
weights_name="linear/linear_model/Accelerated_Healing/weights/part_0/Ftrl"
est.get_variable_value(weights_name)

# %%
weights_name="linear/linear_model/Accelerated_Healing/weights/part_0/Ftrl_1"
est.get_variable_value(weights_name)

# %%
feature="bias_weights"
weights={x:est.get_variable_value(x) for x in est.get_variable_names() if feature in x}
weights

# %%
feature="Omniscient"
weights={x:est.get_variable_value(x) for x in est.get_variable_names() if feature in x}
weights

# %% [markdown]
# # INFERENCE: GOOGLE CLOUD ML ENGINE

# %%
PROJECT="injenia-ricerca"
MODEL=""
VERSION=None

# %%
from oauth2client.client import GoogleCredentials
import googleapiclient
import json
import os
import pandas as pd
import base64
import tensorflow as tf
from tensorflow.python.lib.io.file_io import FileIO as open_file

# %%
with open_file(os.path.join(MODEL_DIR,"data","latest_model.txt"), "r") as f:
    MODEL_PATH=f.read()
MODEL_PATH
with open_file(os.path.join(MODEL_DIR,"data","dataset_fields.json"), "r") as f:
    inputs_definition=json.load(f)
    
COLUMNS=inputs_definition["fields"]["columns"]
FIELD_TYPES=inputs_definition["fields"]["types"]
FIELD_CATEGORIES=inputs_definition["fields"]["categories"]
LABELS=inputs_definition["label"]["categories"]

# %%
with open_file(os.path.join(MODEL_DIR,"data","actual_dataset.csv"), "r") as f:
    df = pd.read_csv(f)
df.columns=[x.strip().replace(" ", "_").replace("_-_", "_") for x in df.columns]
df = df[df["Alignment"].isin(["good","bad","neutral"]) ]
#df = df.drop(["Publisher"], axis=1)
for c in COLUMNS:
    if df[c].dtypes.name == 'bool':
        df[c]=df[c].map({True: 'TRUE', False: 'FALSE'})

# %%
superman_feats = list(df[df["index"]=="Superman"].drop(["Alignment"], axis=1).values[0][1:])
feats=superman_feats

# %%
def _float_feature(value):
    return tf.train.Feature(float_list=tf.train.FloatList(value=[value]))

def _bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))

def build_cmle_request(COLUMNS, FIELD_TYPES, feats):    
    #COLUMNS=data["COLUMNS"]
    #FIELD_TYPES=data["FIELD_TYPES"]
    #feats=data["features"]
    
    feature_dict={}

    for i,c in enumerate(COLUMNS):
        if FIELD_TYPES[c]=="string":
            feature_dict[c]=_bytes_feature(value=feats[i].encode())
        if FIELD_TYPES[c]=="number":
            feature_dict[c]=_float_feature(value=feats[i])


    example = tf.train.Example(features=tf.train.Features(feature=feature_dict))
    serialized = example.SerializeToString()

    return {"inputs":serialized}
    #return serialized

instances=[build_cmle_request(COLUMNS, FIELD_TYPES, feats)]
instances

# %%
def execute_request(project,model,version=None,instances=[]):
    service = googleapiclient.discovery.build('ml', 'v1')
    name = 'projects/{}/models/{}'.format(project, model)
    if version is not None:
        name += '/versions/{}'.format(version)

    response = service.projects().predict(
        name=name,
        body={'instances': instances}
    ).execute()

    return response

resp=execute_request(PROJECT,MODEL,VERSION,instances)
resp
